# %%
import pm4py

log = pm4py.read_xes("filter_1prc.xes")
log
# Out:
# d:\Programs\Programming\Python\lib\site-packages\pm4py\util\dt_parsing\parser.py:82: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/12 [00:00<?, ?it/s]
#                             concept:name                   time:timestamp  \
# 0       Start:Collections.SegmentedArray 2025-01-10 20:01:47.524784+00:00
# 1       Start:Collections.SegmentedArray 2025-01-10 20:01:47.524906+00:00
# 2         End:Collections.SegmentedArray 2025-01-10 20:01:47.525261+00:00
# 3       Start:Collections.SegmentedArray 2025-01-10 20:01:47.525328+00:00
# 4         End:Collections.SegmentedArray 2025-01-10 20:01:47.525448+00:00
# ...                                  ...                              ...
# 593033  Start:Collections.SegmentedArray 2025-01-10 20:03:37.598480+00:00
# 593034    End:Collections.SegmentedArray 2025-01-10 20:03:37.598480+00:00
# 593035  Start:Collections.SegmentedArray 2025-01-10 20:03:37.598480+00:00
# 593036    End:Collections.SegmentedArray 2025-01-10 20:03:37.598481+00:00
# 593037    End:Collections.SegmentedArray 2025-01-10 20:03:37.598481+00:00
#
#         ManagedThreadId  NativeThreadId        QpcStamp  concept:instance  \
# 0                 25452           25452  13371930871278               NaN
# 1                 25452           25452  13371930872504               NaN
# 2                 25452           25452  13371930876056               NaN
# 3                 25452           25452  13371930876722               NaN
# 4                 25452           25452  13371930877918               NaN
# ...                 ...             ...             ...               ...
# 593033            18968           18968  13373031595316               NaN
# 593034            18968           18968  13373031595320               NaN
# 593035            18968           18968  13373031595321               NaN
# 593036            18968           18968  13373031595326               NaN
# 593037            18968           18968  13373031595327               NaN
#
#         lifecycle:transition                  start_timestamp  \
# 0                        NaN 2025-01-10 20:01:47.524784+00:00
# 1                        NaN 2025-01-10 20:01:47.524906+00:00
# 2                        NaN 2025-01-10 20:01:47.525261+00:00
# 3                        NaN 2025-01-10 20:01:47.525328+00:00
# 4                        NaN 2025-01-10 20:01:47.525448+00:00
# ...                      ...                              ...
# 593033                   NaN 2025-01-10 20:03:37.598480+00:00
# 593034                   NaN 2025-01-10 20:03:37.598480+00:00
# 593035                   NaN 2025-01-10 20:03:37.598480+00:00
# 593036                   NaN 2025-01-10 20:03:37.598481+00:00
# 593037                   NaN 2025-01-10 20:03:37.598481+00:00
#
#        case:concept:name
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 593033                12
# 593034                12
# 593035                12
# 593036                12
# 593037                12
#
# [593038 rows x 9 columns]

# %%
log["case:concept:name"].value_counts()
# Out:
# case:concept:name
# 4     127632
# 2      50014
# 9      47968
# 10     47234
# 7      43574
# 8      43574
# 3      41948
# 5      41008
# 11     38948
# 1      38514
# 6      37400
# 12     35224
# Name: count, dtype: int64

# %%
trace8 = log[log["case:concept:name"] == '8']

# %% [markdown]
# ### DFG

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(log)
pm4py.view_dfg(dfg, start_activities, end_activities)

# %% [markdown]
# ### Heuristic

# %%
heuristics_net = pm4py.discover_heuristics_net(
    log,
    dependency_threshold = 0,
    and_threshold = 0,
    loop_two_threshold = 0,
    min_act_count = 0,
    min_dfg_occurrences = 0
)
pm4py.view_heuristics_net(heuristics_net)
