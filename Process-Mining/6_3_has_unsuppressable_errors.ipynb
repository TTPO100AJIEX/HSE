# %%
import pm4py

src_log = pm4py.read_xes("5_has_unsuppressable_errors.xes")
# Out:
# d:\Programs\Programming\Python\lib\site-packages\pm4py\util\dt_parsing\parser.py:82: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/22 [00:00<?, ?it/s]

# %%
display(src_log["case:concept:name"].value_counts())
display(src_log["concept:name"].value_counts())
# Out:
# case:concept:name
# 3     152
# 5     128
# 17     96
# 1      64
# 7      64
# 13     56
# 9      56
# 11     48
# 19     48
# 15     48
# 21     48
# 10      6
# 12      6
# 8       6
# 14      6
# 6       6
# 16      6
# 4       6
# 18      6
# 2       6
# 20      6
# 0       6
# Name: count, dtype: int64
# concept:name
# End:DiagnosticInfo.get_Severity                 158
# Start:DiagnosticInfo.get_Severity               158
# Start:DiagnosticWithInfo.get_Info                90
# End:DiagnosticWithInfo.get_Info                  90
# End:DiagnosticWithInfo.get_Severity              68
# Start:DiagnosticWithInfo.get_Severity            68
# Start:DiagnosticBag.AsEnumerable                 22
# Start:CommonCompiler.HasUnsuppressableErrors     22
# End:CommonCompiler.HasUnsuppressableErrors       22
# End:DiagnosticBag.AsEnumerable                   22
# End:DiagnosticBag.get_Bag                        22
# Start:DiagnosticBag.get_Bag                      22
# ...

# %%
pm4py.view_heuristics_net(pm4py.discover_heuristics_net(src_log))
