# %% [markdown]
# ## Занятие 7
# ## Математический анализ
# ## Исследование функции с sympy.calculus.util и sympy.calculus.singularities

# %%
import sympy
from sympy import S, Interval, plot
from sympy import sin as Sin
from sympy import cos as Cos
from sympy import exp as Exp
from sympy import log as Log
from sympy import pi as Pi
from sympy.calculus.util import continuous_domain, function_range, periodicity, stationary_points, maximum, minimum, AccumBounds
from sympy.calculus.singularities import singularities, is_increasing, is_decreasing, is_monotonic
from sympy.calculus.singularities import is_strictly_increasing, is_strictly_decreasing
# %matplotlib inline

# %% [markdown]
# ## Схема анализа функции.
# 1. Область определения
#
# sympy.calculus.util.continuous_domain(f, symbol, domain)
#
# f - выражение, описывающее функцию,
#
# symbol - переменная, от которой зависит исследуемая функция,
#
# domain - область значений переменной, на которой рассматривается функция,
#
# если функция рассматривается на всей вещественной прямой, то domain=S.Reals
#
# Сингулярные точки (точки, в которых функция не существует) находятся с помощью
#
# sympy.calculus.singularities.singularities(f, symbol, domain=None)
#
# 2. Область значений
#
# sympy.calculus.util.function_range(f, symbol, domain)
#
# 3. Периодичность
#
# sympy.calculus.util.periodicity(f, symbol, check=False)
#
# 4. Стационарные точки
#
# sympy.calculus.util.stationary_points(f, symbol, domain=Reals)
#
# 5. Точки экстремума
#
# sympy.calculus.util.maximum(f, symbol, domain=Reals)
#
# sympy.calculus.util.minimum(f, symbol, domain=Reals)
#
# 6. Монотонность
#
# sympy.calculus.singularities.is_decreasing(f, interval=Reals, symbol=None)
#
# sympy.calculus.singularities.is_increasing(f, interval=Reals, symbol=None)
#
# sympy.calculus.singularities.is_monotonic(f, interval=Reals, symbol=None)
#
# sympy.calculus.singularities.is_strictly_decreasing(f, interval=Reals, symbol=None)
#
# sympy.calculus.singularities.is_strictly_increasing(f, interval=Reals, symbol=None)
#
# 7. Минимальное и максимальное значение функции на интервале
#
# sympy.calculus.util.AccumulationBounds(min, max)
#
# Свойства: delta, max, min, mid
#
# ### Задание 1.
# Исследовать функцию по п.1 - 5 на области определения и по п. 1 - 7 на одном периоде, построить график.
# $$
# f(x) = e^{\sin(x)}.
# $$
# ###### 1. Область определения

# %%
x = sympy.Symbol('x')
f = sympy.E ** sympy.sin(x)
D = continuous_domain(f, x, S.Reals)
D
# Out:
# Reals

# %% [markdown]
# Сингулярные точки (точки, где функция не определена)

# %%
singularities(f, x)
# Out:
# EmptySet

# %% [markdown]
# ###### 2. Область значений

# %%
function_range(f, x, S.Reals)
# Out:
# Interval(exp(-1), E)

# %% [markdown]
# ###### 3. Периодичность

# %%
periodicity(f, x, check=False)
# Out:
# 2*pi

# %% [markdown]
# ###### 4. Стационарные точки

# %%
stationary_points(f, x)
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + pi/2), Integers), ImageSet(Lambda(_n, 2*_n*pi + 3*pi/2), Integers))

# %% [markdown]
# ###### 5. Максимальное и минимальное значения функции

# %%
display(maximum(f, x), minimum(f, x))
# Out:
# E
# exp(-1)

# %% [markdown]
# ##### Исследование периодической функции на одном периоде.
# Найти пересечение с периодом области определения, множества сингулярных точек и стационарных точек.
#
#
# ###### 1. Область определения

# %%
period = Interval(0, periodicity(f, x, check=False))
continuous_domain(f, x, period)
# Out:
# Interval(0, 2*pi)

# %% [markdown]
# Сингулярные точки (точки, где функция не определена)

# %%
singularities(f, x, period)
# Out:
# EmptySet

# %% [markdown]
# ###### 2. Область значений

# %%
function_range(f, x, period)
# Out:
# Interval(exp(-1), E)

# %% [markdown]
# ###### 4. Стационарные точки

# %%
stationary_points(f, x, period)
# Out:
# FiniteSet(pi/2, 3*pi/2)

# %% [markdown]
# ###### 5. Максимальное и минимальное значения функции

# %%
display(maximum(f, x, period), minimum(f, x, period))
# Out:
# E
# exp(-1)

# %% [markdown]
# ###### 6. Монотонность
# Исследовать на периоде открытые интервалы (Interval.open), на которые период разбивают стационарные точки.

# %%
intervals = [Interval.open(0, Pi / 2), Interval.open(Pi / 2, 3 * Pi / 2), Interval.open(3 * Pi / 2, 2 * Pi)]
for interval in intervals:
  display(interval)
  print(is_monotonic(f, interval=interval), is_decreasing(f, interval=interval), is_increasing(f, interval=interval), is_strictly_decreasing(f, interval=interval), is_strictly_increasing(f, interval=interval))
# Out:
# Interval.open(0, pi/2)
# True None None None None
# Interval.open(pi/2, 3*pi/2)
# True None None None None
# Interval.open(3*pi/2, 2*pi)
# True None None None None

# %% [markdown]
# ###### 7. Минимальное и максимальное значение функции на интервале
# Найти максимальное и минимальное значение функции на каждом из интервалов монотонности в пределах одного периода

# %%
for interval in intervals:
  display(interval)
  left = [*interval.boundary][0]
  right = [*interval.boundary][1]
  f_AccB = f.subs(x, AccumBounds(left, right))
  display(f_AccB, f_AccB.max, f_AccB.min, f_AccB.delta, f_AccB.mid)
# Out:
# Interval.open(0, pi/2)
# AccumBounds(1, E)
# E
# 1
# -1 + E
# 1/2 + E/2
# Interval.open(pi/2, 3*pi/2)
# AccumBounds(exp(-1), E)
# E
# exp(-1)
# E - exp(-1)
# exp(-1)/2 + E/2
# Interval.open(3*pi/2, 2*pi)
# AccumBounds(exp(-1), 1)
# 1
# exp(-1)
# 1 - exp(-1)
# exp(-1)/2 + 1/2

# %% [markdown]
# ###### График функции на одном периоде.

# %%
plot((f, (x, 0, 2 * Pi)))

# %% [markdown]
# ### Задание 2.
# Исследовать функцию по п.1 - 5 на области определения и по п. 1 - 7  на одном периоде, построить график.
# $$
# f(x) = \frac{1}{\sin(x) + \cos(x)}.
# $$
# ###### 1. Область определения

# %%
f = 1 / (sympy.sin(x) + sympy.cos(x))
D = continuous_domain(f, x, S.Reals)
D
# Out:
# Complement(Reals, Union(ImageSet(Lambda(_n, 2*_n*pi + 3*pi/4), Integers), ImageSet(Lambda(_n, 2*_n*pi + 7*pi/4), Integers)))

# %% [markdown]
# Сингулярные точки (точки, где функция не определена)

# %%
singularities(f, x)
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi + 3*pi/4), Integers), ImageSet(Lambda(_n, 2*_n*pi + 7*pi/4), Integers))

# %% [markdown]
# ###### 2. Область значений

# %%
function_range(f, x, S.Reals)
# Out:
# Union(Interval(-oo, -sqrt(2)/2), Interval(sqrt(2)/2, oo))

# %% [markdown]
# ###### 3. Периодичность

# %%
periodicity(f, x, check=False)
# Out:
# 2*pi

# %% [markdown]
# ###### 4. Стационарные точки

# %%
stationary_points(f, x)
# Out:
# Union(Complement(ImageSet(Lambda(_n, 2*_n*pi + 5*pi/4), Integers), Union(ImageSet(Lambda(_n, 2*_n*pi + 3*pi/4), Integers), ImageSet(Lambda(_n, 2*_n*pi + 7*pi/4), Integers))), Complement(ImageSet(Lambda(_n, 2*_n*pi + pi/4), Integers), Union(ImageSet(Lambda(_n, 2*_n*pi + 3*pi/4), Integers), ImageSet(Lambda(_n, 2*_n*pi + 7*pi/4), Integers))))

# %% [markdown]
# ###### 5. Максимальное и минимальное значения функции

# %%
display(maximum(f, x), minimum(f, x))
# Out:
# oo
# -oo

# %% [markdown]
# ##### Исследование периодической функции на одном периоде.
# Найти пересечение с периодом области определения, множества сингулярных точек и стационарных точек.
# ###### 1. Область определения

# %%
period = Interval(0, periodicity(f, x, check=False))
continuous_domain(f, x, period)
# Out:
# Union(Interval.Ropen(0, 3*pi/4), Interval.open(3*pi/4, 7*pi/4), Interval.Lopen(7*pi/4, 2*pi))

# %% [markdown]
# Сингулярные точки (точки, где функция не определена)

# %%
singularities(f, x, period)
# Out:
# FiniteSet(3*pi/4, 7*pi/4)

# %% [markdown]
# ###### 2. Область значений

# %%
function_range(f, x, period)
# Out:
# Union(Interval(-oo, -sqrt(2)/2), Interval(sqrt(2)/2, oo))

# %% [markdown]
# ###### 4. Стационарные точки

# %%
stationary_points(f, x, period)
# Out:
# FiniteSet(pi/4, 5*pi/4)

# %% [markdown]
# ###### 5. Максимальное и минимальное значения функции

# %%
display(maximum(f, x, period), minimum(f, x, period))
# Out:
# oo
# -oo

# %% [markdown]
# ###### 6. Монотонность

# %%
intervals = [Interval.open(0, Pi / 4), 
             Interval.open(Pi / 4, 3 * Pi / 4), 
             Interval.open(3 * Pi / 4, 5 * Pi / 4), 
             Interval.open(5 * Pi / 4, 7 * Pi / 4), 
             Interval.open(7 * Pi / 4, 2 * Pi)]
for interval in intervals:
  display(interval)
  print(is_monotonic(f, interval=interval), is_decreasing(f, interval=interval), is_increasing(f, interval=interval), is_strictly_decreasing(f, interval=interval), is_strictly_increasing(f, interval=interval))
# Out:
# Interval.open(0, pi/4)
# True True False True False
# Interval.open(pi/4, 3*pi/4)
# True False True False True
# Interval.open(3*pi/4, 5*pi/4)
# True False True False True
# Interval.open(5*pi/4, 7*pi/4)
# True True False True False
# Interval.open(7*pi/4, 2*pi)
# True True False True False

# %% [markdown]
# ###### 7. Минимальное и максимальное значение функции на периоде

# %%
for interval in intervals:
  display(interval)
  left = [*interval.boundary][0]
  right = [*interval.boundary][1]
  f_AccB = f.subs(x, AccumBounds(left, right))
  display(f_AccB, f_AccB.max, f_AccB.min, f_AccB.delta, f_AccB.mid)
# Out:
# Interval.open(0, pi/4)
# AccumBounds(1/(sqrt(2)/2 + 1), sqrt(2))
# sqrt(2)
# 1/(sqrt(2)/2 + 1)
# -1/(sqrt(2)/2 + 1) + sqrt(2)
# 1/(2*(sqrt(2)/2 + 1)) + sqrt(2)/2
# Interval.open(pi/4, 3*pi/4)
# AccumBounds(1/(sqrt(2)/2 + 1), oo)
# oo
# 1/(sqrt(2)/2 + 1)
# oo
# oo
# Interval.open(3*pi/4, 5*pi/4)
# AccumBounds(-oo, 1/(-1 - sqrt(2)/2))
# 1/(-1 - sqrt(2)/2)
# -oo
# oo
# -oo
# Interval.open(5*pi/4, 7*pi/4)
# AccumBounds(-oo, 1/(-1 - sqrt(2)/2))
# 1/(-1 - sqrt(2)/2)
# -oo
# oo
# -oo
# Interval.open(7*pi/4, 2*pi)
# AccumBounds(1, oo)
# oo
# 1
# oo
# oo

# %% [markdown]
# ###### График

# %%
plot((f, (x, 0 + 0.1, 3 * Pi / 4 - 0.1)), 
     (f, (x, 3 * Pi / 4 + 0.1, 7 * Pi / 4 - 0.1)), 
     (f, (x, 7 * Pi / 4 + 0.1, 2 * Pi - 0.1)))

# %% [markdown]
# ### Индивидуальное задание.
# Исследовать функцию, найти область определения, сингулярные точки, область значений, стационарные точки, минимальное и максимальное значение, построить график.
#
#  Вариант 2
#
# $f(x) = 2 \sqrt{4 - 7 \sin{\left(x \right)}}$
#
# ###### 1. Область определения

# %%
f = 2 * sympy.sqrt(4 - 7 * sympy.sin(x))
D = continuous_domain(f, x, S.Reals)
D
# Out:
# Union(Interval(0, atan(4*sqrt(33)/33)), Interval.Ropen(pi - atan(4*sqrt(33)/33), 2*pi))

# %% [markdown]
# Сингулярные точки (точки, где функция не определена)

# %%
singularities(f, x)
# Out:
# EmptySet

# %% [markdown]
# ###### 2. Область значений

# %%
function_range(f, x, S.Reals)
# Out:
# Interval(0, 2*sqrt(11))

# %% [markdown]
# ###### 3. Периодичность

# %%
periodicity(f, x, check=False)
# Out:
# 2*pi

# %% [markdown]
# ###### 4. Стационарные точки

# %%
stationary_points(f, x)
# Out:
# FiniteSet(3*pi/2)

# %% [markdown]
# ###### 5. Максимальное и минимальное значения функции

# %%
display(maximum(f, x), minimum(f, x))
# Out:
# 2*sqrt(11)
# 0

# %% [markdown]
# ###### 6. Монотонность

# %%
#intervals = [Interval.open(-Pi - sympy.asin(4 / 7), -Pi / 2),
#             Interval.open(-Pi / 2, sympy.asin(4 / 7))]
#for interval in intervals:
#  display(interval)
#  print(is_monotonic(f, interval=interval), is_decreasing(f, interval=interval), is_increasing(f, interval=interval), is_strictly_decreasing(f, interval=interval), is_strictly_increasing(f, interval=interval))
display(is_decreasing(f), is_increasing(f), is_monotonic(f), is_strictly_decreasing(f), is_strictly_increasing(f))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-40-2bf6ca0f4c1c> in <module>()
#       4 #  display(interval)
#       5 #  print(is_monotonic(f, interval=interval), is_decreasing(f, interval=interval), is_increasing(f, interval=interval), is_strictly_decreasing(f, interval=interval), is_strictly_increasing(f, interval=interval))
# ----> 6 display(is_decreasing(f), is_increasing(f), is_monotonic(f), is_strictly_decreasing(f), is_strictly_increasing(f))
#
# /usr/local/lib/python3.7/dist-packages/sympy/calculus/singularities.py in is_decreasing(expression, interval, symbol)
#     283
#     284     """
# --> 285     return monotonicity_helper(expression, lambda x: x <= 0, interval, symbol)
#     286
#     287
#
# /usr/local/lib/python3.7/dist-packages/sympy/calculus/singularities.py in monotonicity_helper(expression, predicate, interval, symbol)
#     153     variable = symbol or (free.pop() if free else Symbol('x'))
#     154     derivative = expression.diff(variable)
# --> 155     predicate_interval = solveset(predicate(derivative), variable, S.Reals)
#     156     return interval.is_subset(predicate_interval)
#     157
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in solveset(f, symbol, domain)
#    2093     if symbol not in _rc:
#    2094         x = _rc[0] if domain.is_subset(S.Reals) else _rc[1]
# -> 2095         rv = solveset(f.xreplace({symbol: x}), x, domain)
#    2096         # try to use the original symbol if possible
#    2097         try:
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in solveset(f, symbol, domain)
#    2117     f = piecewise_fold(f)
#    2118
# -> 2119     return _solveset(f, symbol, domain, _check=True)
#    2120
#    2121
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solveset(f, symbol, domain, _check)
#    1030         try:
#    1031             result = solve_univariate_inequality(
# -> 1032             f, symbol, domain=domain, relational=False)
#    1033         except NotImplementedError:
#    1034             result = ConditionSet(symbol, f, domain)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/inequalities.py in solve_univariate_inequality(expr, gen, relational, domain, continuous)
#     602                 im_sol = FiniteSet()
#     603                 try:
# --> 604                     a = solveset(im(expanded_e), gen, domain)
#     605                     if not isinstance(a, Interval):
#     606                         for z in a:
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in solveset(f, symbol, domain)
#    2117     f = piecewise_fold(f)
#    2118
# -> 2119     return _solveset(f, symbol, domain, _check=True)
#    2120
#    2121
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solveset(f, symbol, domain, _check)
#    1060                         result += _solve_radical(equation,
#    1061                                                  symbol,
# -> 1062                                                  solver)
#    1063                     elif equation.has(Abs):
#    1064                         result += _solve_abs(f, symbol, domain)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solve_radical(f, symbol, solveset_solver)
#     833     eq, cov = res if res else (f, [])
#     834     if not cov:
# --> 835         result = solveset_solver(eq, symbol) - \
#     836             Union(*[solveset_solver(g, symbol) for g in denoms(f, symbol)])
#     837     else:
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in <lambda>(f, x, domain)
#     988
#     989     # assign the solvers to use
# --> 990     solver = lambda f, x, domain=domain: _solveset(f, x, domain)
#     991     inverter = lambda f, rhs, symbol: _invert(f, rhs, symbol, domain)
#     992
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solveset(f, symbol, domain, _check)
#    1060                         result += _solve_radical(equation,
#    1061                                                  symbol,
# -> 1062                                                  solver)
#    1063                     elif equation.has(Abs):
#    1064                         result += _solve_abs(f, symbol, domain)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solve_radical(f, symbol, solveset_solver)
#     833     eq, cov = res if res else (f, [])
#     834     if not cov:
# --> 835         result = solveset_solver(eq, symbol) - \
#     836             Union(*[solveset_solver(g, symbol) for g in denoms(f, symbol)])
#     837     else:
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in <lambda>(f, x, domain)
#     988
#     989     # assign the solvers to use
# --> 990     solver = lambda f, x, domain=domain: _solveset(f, x, domain)
#     991     inverter = lambda f, rhs, symbol: _invert(f, rhs, symbol, domain)
#     992
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solveset(f, symbol, domain, _check)
#    1060                         result += _solve_radical(equation,
#    1061                                                  symbol,
# -> 1062                                                  solver)
#    1063                     elif equation.has(Abs):
#    1064                         result += _solve_abs(f, symbol, domain)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in _solve_radical(f, symbol, solveset_solver)
#     833     eq, cov = res if res else (f, [])
#     834     if not cov:
# --> 835         result = solveset_solver(eq, symbol) - \
#     836             Union(*[solveset_solver(g, symbol) for g in denoms(f, symbol)])
#     837     else:
#
# ... last 8 frames repeated, from the frame below ...
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/solveset.py in <lambda>(f, x, domain)
#     988
#     989     # assign the solvers to use
# --> 990     solver = lambda f, x, domain=domain: _solveset(f, x, domain)
#     991     inverter = lambda f, rhs, symbol: _invert(f, rhs, symbol, domain)
#     992
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# ###### 7. Минимальное и максимальное значение функции на интервале

# %%
for interval in intervals:
  display(interval)
  left = [*interval.boundary][1]
  right = [*interval.boundary][0]
  f_AccB = f.subs(x, AccumBounds(left, right))
  display(f_AccB, f_AccB.max, f_AccB.min, f_AccB.delta, f_AccB.mid)
# Out:
# Interval.open(-pi - 0.60824557891021, -pi/2)
# AccumBounds(0, 2*sqrt(11))
# 2*sqrt(11)
# 0
# 2*sqrt(11)
# sqrt(11)
# Interval.open(-pi/2, 0.608245578910210)
# AccumBounds(0, 2*sqrt(11))
# 2*sqrt(11)
# 0
# 2*sqrt(11)
# sqrt(11)

# %% [markdown]
# ###### График

# %%
plot((f, (x, -Pi - sympy.asin(4 / 7), sympy.asin(4 / 7))))

plot((f, (x, -10, 10)))
