# %%
import time

import tqdm
import torch
import numpy
import wandb
import random
import pandas
import torchvision
import matplotlib.pyplot as plt
import torch.utils.data as torchdata
from sklearn.metrics import accuracy_score, roc_auc_score, top_k_accuracy_score, precision_score, recall_score, f1_score, classification_report

TRAIN_BATCH_SIZE = 512
TEST_BATCH_SIZE = 256
N_EPOCHS = 25

RANDOM_STATE = 42

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
print(device)

def set_random_seed(seed):
    random.seed(seed)
    numpy.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
set_random_seed(RANDOM_STATE)
# Out:
# cuda

# %%
# Transforms
transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(
        mean = torch.tensor([ 0.491, 0.482, 0.446 ]),
        std = torch.tensor([ 0.247, 0.243, 0.261 ])
    )
])

# Load dataset
train_set = torchvision.datasets.CIFAR10('cifar-10', train = True, download = True, transform = transforms)
test_set = torchvision.datasets.CIFAR10('cifar-10', train = False, download = True, transform = transforms)

# Dataloaders
train_loader = torchdata.DataLoader(train_set, batch_size = TRAIN_BATCH_SIZE, shuffle = True)
test_loader = torchdata.DataLoader(test_set, batch_size = TEST_BATCH_SIZE, shuffle = False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Denormalization
denormalize = torchvision.transforms.Compose([
    torchvision.transforms.Normalize(
        mean = [ 0., 0., 0. ],
        std = 1 / transforms.transforms[1].std
    ),
    torchvision.transforms.Normalize(
        mean = -transforms.transforms[1].mean,
        std = [ 1., 1., 1. ]
    )
])

# Display some samples
plt.rcParams["figure.figsize"] = (20, 10)
for i in range(10):
    image, class_num = train_set[i]
    plt.subplot(1, 10, i + 1)
    plt.imshow(denormalize(image).permute(1, 2, 0))
    plt.axis('off')
    plt.title('{} ({})'.format(train_set.classes[class_num], str(class_num)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Validation function. Don't cahnge it
def validate(model,testloader):
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %% [markdown]
# # 1. Multi layer perceptron
#
# Implement CIFAR10 classifier using a fully connected neural network.

# %%
class TwoLayerFCN(torch.nn.Module):
    def __init__(self, classes: int = 10):
        super().__init__()
        self.model = torch.nn.Sequential(
            torch.nn.Flatten(),
            torch.nn.Linear(3072, 500),
            torch.nn.ReLU(),
            torch.nn.Linear(500, classes)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Train your model

# %%
wandb.login(anonymous = "allow")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ttpo100ajiex (hse-iad). Use `wandb login --relogin` to force relogin
# True

# %%
def calc_metrics(model) -> dict:
    model.eval() # Enter evaluation mode
    model = model.to(device) # To GPU
    with torch.no_grad():
        y_predicted = numpy.array([])
        y_true = numpy.array([])
        scores = numpy.empty((0, 10))
        for images, labels in test_loader:
            # To GPU
            images = images.to(device)
            labels = labels.to(device)

            # Get predictions
            outputs = torch.nn.Softmax(dim = 1)(model(images))
            predicted = torch.argmax(outputs, dim = 1)

            # Store predictions
            y_predicted = numpy.append(y_predicted, predicted.cpu().detach().numpy())
            y_true = numpy.append(y_true, labels.cpu().detach().numpy())
            scores = numpy.concatenate([ scores, outputs.cpu().detach().numpy() ])

    return {
        'Accuracy': accuracy_score(y_true, y_predicted),
        'TOP-2 Accuracy': top_k_accuracy_score(y_true, scores, k = 2),
        'TOP-3 Accuracy': top_k_accuracy_score(y_true, scores, k = 3),
        'TOP-4 Accuracy': top_k_accuracy_score(y_true, scores, k = 4),
        'TOP-5 Accuracy': top_k_accuracy_score(y_true, scores, k = 5),
        'TOP-6 Accuracy': top_k_accuracy_score(y_true, scores, k = 6),
        'TOP-7 Accuracy': top_k_accuracy_score(y_true, scores, k = 7),
        'TOP-8 Accuracy': top_k_accuracy_score(y_true, scores, k = 8),
        'TOP-9 Accuracy': top_k_accuracy_score(y_true, scores, k = 9),
        'AUC-ROC': roc_auc_score(y_true, scores, multi_class = 'ovo'),
        'Precision': precision_score(y_true, y_predicted, average = 'macro'),
        'Recall': recall_score(y_true, y_predicted, average = 'macro'),
        'F1-score': f1_score(y_true, y_predicted, average = 'macro')
    }

# %%
def train(
    name: str,
    model: torch.nn.Module,
    criterion: torch.nn.Module,
    optimizer: torch.optim.Optimizer
):    
    # Start wandb
    wandb.init(project = "NIS-HW-3", name = name, anonymous = "allow", config = {
        'model': str(model),
        'criterion': str(criterion),
        'optimizer': str(optimizer)
    })
    wandb.watch(model, log = "all")
    
    # Define metrics - does not work for some reason: metrics disappear from the summary (?)
    # wandb.define_metric('Accuracy',        summary = 'best', goal = 'maximize')
    # wandb.define_metric('TOP-2 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-3 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-4 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-5 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-6 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-7 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-8 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('TOP-9 Accuracy',  summary = 'none', goal = 'maximize')
    # wandb.define_metric('AUC-ROC',         summary = 'best', goal = 'maximize')
    # wandb.define_metric('Precision',       summary = 'best', goal = 'maximize')
    # wandb.define_metric('Recall',          summary = 'best', goal = 'maximize')
    # wandb.define_metric('F1-score',        summary = 'best', goal = 'maximize')
    # wandb.define_metric('Loss',            summary = 'last', goal = 'minimize')
    # wandb.define_metric('Train time',      summary = 'mean', goal = 'minimize')
    # wandb.define_metric('Validation time', summary = 'mean', goal = 'minimize')

    best_metrics = None
    model = model.to(device) # To GPU
    for epoch in tqdm.trange(N_EPOCHS):
        model.train() # Enter train mode
        train_start = time.perf_counter()
        for images, labels in train_loader:
            # To GPU
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad() # Zero gradients
            output = model(images) # Get predictions
            loss = criterion(output, labels) # Calculate loss
            loss.backward() # Calculate gradients
            optimizer.step() # Update weights

        train_time = time.perf_counter() - train_start # Calculate train time

        val_start = time.perf_counter()
        metrics = calc_metrics(model) # Calculate metrics
        val_time = time.perf_counter() - val_start # Calculate validation time

        # Save to wandb
        metrics['Loss'] = loss.item()
        metrics['Train time'] = train_time
        metrics['Validation time'] = val_time
        wandb.log(metrics)

        if (best_metrics is None) or (metrics['Accuracy'] > best_metrics['Accuracy']):
            best_metrics = metrics

    wandb.finish() # Finish wandb run
    best_metrics['Name'] = name
    return best_metrics

# %% [markdown]
# # 2. Compare different optimizators
#
# * Take three different optimizers e.g.: SGD, SGD with momentum, AdamW.
# * Train the model with each of them.
# * Plot the loss curve for different optimizers in same axis
#
#
# *Because this task is time consuming it is recommended to perform calculations on a small piece of datastat*

# %%
results = [ ]

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters())
results.append(train("AdamW", model, criterion, optimizer))
# Out:
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_174106-cowizmap</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/cowizmap' target="_blank">AdamW</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/cowizmap' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/cowizmap</a>
# 100%|██████████| 25/25 [02:31<00:00,  6.07s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.337924…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▄▅▆▆▆▇▇█▆▇███▇██▇▆▇▆▆▆▇▆</td></tr><tr><td>Accuracy</td><td>▁▄▄▅▅▇▇▇▇▆▅▇██▇▇▇▇▆▇▇▆▇▇▆</td></tr><tr><td>F1-score</td><td>▁▄▄▅▅▇▇▇▇▆▅███▇▇▇▇▇█▇▆▇▇▇</td></tr><tr><td>Loss</td><td>██▆▇▆▅▅▅▅▄▃▄▄▃▃▃▂▂▂▂▂▁▁▂▁</td></tr><tr><td>Precision</td><td>▁▄▅▅▆█▇▆▇▆▅▇███▇▇▇▇█▆▇▇▇█</td></tr><tr><td>Recall</td><td>▁▄▄▅▅▇▇▇▇▆▅▇██▇▇▇▇▆▇▇▆▇▇▆</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▄▅▆▆▆▇▇█▆▆███▇▇▇▇▆█▆▇▆▆▆</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▅▅▆▆▆▇▇█▆▆█▇█▇▇█▇▇▇▆▇▆▆▆</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▅▅▅▆▆▆▇▇▆▆███▇▇▇▇▇▇▆▇▆▇▆</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▅▆▆▆▇▇▇▆▆█▇▇▇▇▇▇▇▇▇▇▆▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▅▅▆▆▆▇▇▇▆▆███▇██▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▄▅▆▆▇▆▇▆▆█▇▇▇▇▇▇▆▇▇▇▆▇▆</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▄▅▆▆▆▆▇▅▅█▇█▆▇▇▇▆▇▆▆▆▇▅</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▄▅▅▅▇█▅█▆█▅▇▇█▆▅▇▅▇█▅▄▄▇</td></tr><tr><td>Train time</td><td>█▇▅▄▃▄▄▄▄▄▄▄▇▃▄▃▃▁▂▂▃▄▂▁▁</td></tr><tr><td>Validation time</td><td>▇▅▁▁▄▄▄▁▂▆▆█▅▁▆▅▂▃▂▂▂▃▂█▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88258</td></tr><tr><td>Accuracy</td><td>0.5204</td></tr><tr><td>F1-score</td><td>0.52342</td></tr><tr><td>Loss</td><td>0.42222</td></tr><tr><td>Precision</td><td>0.53654</td></tr><tr><td>Recall</td><td>0.5204</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7116</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8119</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8811</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9276</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9572</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9747</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9864</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9958</td></tr><tr><td>Train time</td><td>4.50661</td></tr><tr><td>Validation time</td><td>1.15172</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">AdamW</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/cowizmap' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/cowizmap</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_174106-cowizmap\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum = 0)
results.append(train("SGD", model, criterion, optimizer))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777776363, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_174343-7t0uz3wx</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/7t0uz3wx' target="_blank">SGD</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/7t0uz3wx' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/7t0uz3wx</a>
# 100%|██████████| 25/25 [02:24<00:00,  5.80s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▃▄▅▆▆▆▆▇▇▇▇▇▇▇█▅▇▅▇█▇▇▆▄</td></tr><tr><td>Accuracy</td><td>▁▃▄▄▅▅▆▅▆▆▆▇▇▇▆▇▄▇▅▇█▇▇▆▄</td></tr><tr><td>F1-score</td><td>▁▃▄▄▅▅▆▅▆▆▆▇▆▇▆▇▄▇▅▇█▇▇▆▃</td></tr><tr><td>Loss</td><td>▇▇▅▅▄▄▃▄▄▂▂▂▃▂▂▂▂▁▂▂▂▂▁▂█</td></tr><tr><td>Precision</td><td>▁▃▄▄▅▆▆▆▇▆▆▇▇▇▇▇▅▇▅▇█▇▇▇▅</td></tr><tr><td>Recall</td><td>▁▃▄▄▅▅▆▅▆▆▆▇▇▇▆▇▄▇▅▇█▇▇▆▄</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▄▄▅▅▆▆▇▆▇▇▇▇▇▇▄▇▅▇█▇▇▆▄</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▄▄▅▅▆▆▇▆▇▇▆▇▇█▅▇▅▇█▇▇▇▃</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▃▄▄▅▆▆▆▇▆▇▇▆▇▇█▅▇▅▇█▇▆▇▂</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▃▅▅▆▆▇▆▇▆▇▇▆▇▇█▅█▆▇█▇▆▇▁</td></tr><tr><td>TOP-6 Accuracy</td><td>▂▄▅▅▆▆▇▇▇▇▇▇▆▇▇█▆▇▆▇█▇▆▇▁</td></tr><tr><td>TOP-7 Accuracy</td><td>▃▅▆▆▇▇▇▇▇▇▇█▇█▇█▆█▆██▇▆█▁</td></tr><tr><td>TOP-8 Accuracy</td><td>▅▆▇▇▇▇████▇█▇███▇█▇███▇█▁</td></tr><tr><td>TOP-9 Accuracy</td><td>▆▇▇▇▇▇▇▇▇▇▇█▇█▇█▇█▇███▇█▁</td></tr><tr><td>Train time</td><td>▆▃▅▂█▂▄▃▅▄▃▄▂▅▃▆▆▂▄▃▇▂▁▂▁</td></tr><tr><td>Validation time</td><td>▃▄▅▃▄▁▃▁▃▅█▁▆▇▃▂▅█▇▃▂▆▅▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.86588</td></tr><tr><td>Accuracy</td><td>0.4723</td></tr><tr><td>F1-score</td><td>0.46318</td></tr><tr><td>Loss</td><td>1.80632</td></tr><tr><td>Precision</td><td>0.49933</td></tr><tr><td>Recall</td><td>0.4723</td></tr><tr><td>TOP-2 Accuracy</td><td>0.6714</td></tr><tr><td>TOP-3 Accuracy</td><td>0.7788</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8401</td></tr><tr><td>TOP-5 Accuracy</td><td>0.8835</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9159</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9407</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9576</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9755</td></tr><tr><td>Train time</td><td>4.47648</td></tr><tr><td>Validation time</td><td>1.22076</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SGD</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/7t0uz3wx' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/7t0uz3wx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_174343-7t0uz3wx\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)
results.append(train("SGD with momentum", model, criterion, optimizer))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89284</td></tr><tr><td>Accuracy</td><td>0.533</td></tr><tr><td>F1-score</td><td>0.53255</td></tr><tr><td>Loss</td><td>0.58186</td></tr><tr><td>Precision</td><td>0.54146</td></tr><tr><td>Recall</td><td>0.533</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7249</td></tr><tr><td>TOP-3 Accuracy</td><td>0.826</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8908</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9317</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9593</td></tr><tr><td>TOP-7 Accuracy</td><td>0.977</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9875</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9954</td></tr><tr><td>Train time</td><td>4.77013</td></tr><tr><td>Validation time</td><td>1.13423</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SGD with momentum</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/sf58d9ur' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/sf58d9ur</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_174614-sf58d9ur\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adagrad(model.parameters())
results.append(train("Adagrad", model, criterion, optimizer))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777776363, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_174851-uo7mu8zx</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/uo7mu8zx' target="_blank">Adagrad</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/uo7mu8zx' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/uo7mu8zx</a>
# 100%|██████████| 25/25 [02:27<00:00,  5.89s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▄▄▅▆▆▇▆▇▆▇▇▇█▇█▆█▇██▇▇▇▇</td></tr><tr><td>Accuracy</td><td>▁▃▃▄▅▆▆▅▆▅▇▇▇▇▇█▆▇▇▇█▇▇▆▇</td></tr><tr><td>F1-score</td><td>▁▃▃▄▅▆▅▅▆▅▆▆▇▇▇█▆▇▇▇█▇▇▆▇</td></tr><tr><td>Loss</td><td>█▇▆▆▅▄▄▄▄▃▃▃▃▃▃▂▂▁▁▂▂▂▁▂▁</td></tr><tr><td>Precision</td><td>▁▃▃▄▅▆▆▆▆▆▆▆▇▇▇█▆▇▇▇█▇▇▇▇</td></tr><tr><td>Recall</td><td>▁▃▃▄▅▆▆▅▆▅▇▇▇▇▇█▆▇▇▇█▇▇▆▇</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▃▄▅▆▆▆▇▆▇▇▇▇▇█▆█▇▇█▇▇▆▇</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▃▅▆▆▆▆▇▆▇▇▇▇▇█▆█▇███▇▆█</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▃▃▅▆▇▇▆▇▆▇▇▇█▇█▇█▇▇██▇▆▇</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▄▅▆▇▇▆▇▆▇█▇▇██▇████▇▇▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▃▃▅▆▇▇▆▇▅▇█▇▇██▇█▇███▇▇▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▃▅▆▇▇▆▆▅▇▇▆▇▇▇▆▇▇▇█▇▇▇▇</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▄▅▆▇▇▇▇▆▇▇▇███▇█▇████▇█</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▄▃▅▆▇▇▇▆▆▆▇▇█▇▇▆█▇█▇▇▇█▇</td></tr><tr><td>Train time</td><td>▄▄▃▅▃▃▄▂▂▁▃▃▄▃▄▄▅▆▅▇▄█▃▆▄</td></tr><tr><td>Validation time</td><td>▇▄▅▆▆█▄▄▆▄▅▄▄▃█▅▄▃▄▁▄▂▅▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89334</td></tr><tr><td>Accuracy</td><td>0.5378</td></tr><tr><td>F1-score</td><td>0.53757</td></tr><tr><td>Loss</td><td>0.77592</td></tr><tr><td>Precision</td><td>0.54014</td></tr><tr><td>Recall</td><td>0.5378</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7274</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8278</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8889</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9278</td></tr><tr><td>TOP-6 Accuracy</td><td>0.958</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9757</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9882</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9959</td></tr><tr><td>Train time</td><td>4.8398</td></tr><tr><td>Validation time</td><td>1.04679</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Adagrad</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/uo7mu8zx' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/uo7mu8zx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_174851-uo7mu8zx\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.ASGD(model.parameters())
results.append(train("ASGD", model, criterion, optimizer))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777776363, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_175125-1rvam76n</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/1rvam76n' target="_blank">ASGD</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/1rvam76n' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/1rvam76n</a>
# 100%|██████████| 25/25 [02:35<00:00,  6.22s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.004 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.343063…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▃▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>Accuracy</td><td>▁▂▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>F1-score</td><td>▁▃▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>Loss</td><td>█▇▆▆▅▄▃▄▄▃▃▃▃▃▃▃▁▁▂▃▃▂▁▂▂</td></tr><tr><td>Precision</td><td>▁▂▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>Recall</td><td>▁▂▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▄▄▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇██████</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇███████</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇████████</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇█████████</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███████</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▃▄▅▅▅▆▆▆▆▇▆▇▇▇▇▇▇███████</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▃▄▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▅▅▆▆▆▇▇▇▇▇▇█████████████</td></tr><tr><td>Train time</td><td>▄▆▅▄▃▄▁█▂▂▃▅▄▁▃▄▃▄▁▃▄▃▃▃▃</td></tr><tr><td>Validation time</td><td>▇█▇▃▂▂▁▁▂▂▃▂▂▄▄▅▄▄▃▄▄▄▄▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88026</td></tr><tr><td>Accuracy</td><td>0.5048</td></tr><tr><td>F1-score</td><td>0.50005</td></tr><tr><td>Loss</td><td>1.38915</td></tr><tr><td>Precision</td><td>0.50111</td></tr><tr><td>Recall</td><td>0.5048</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7018</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8069</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8739</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9198</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9506</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9729</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9868</td></tr><tr><td>TOP-9 Accuracy</td><td>0.995</td></tr><tr><td>Train time</td><td>4.98373</td></tr><tr><td>Validation time</td><td>1.0971</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ASGD</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/1rvam76n' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/1rvam76n</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_175125-1rvam76n\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = TwoLayerFCN(10).to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.NAdam(model.parameters())
results.append(train("NAdam", model, criterion, optimizer))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88465</td></tr><tr><td>Accuracy</td><td>0.5277</td></tr><tr><td>F1-score</td><td>0.52442</td></tr><tr><td>Loss</td><td>0.80167</td></tr><tr><td>Precision</td><td>0.53188</td></tr><tr><td>Recall</td><td>0.5277</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7183</td></tr><tr><td>TOP-3 Accuracy</td><td>0.817</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8812</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9261</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9561</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9738</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9869</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9951</td></tr><tr><td>Train time</td><td>5.10352</td></tr><tr><td>Validation time</td><td>1.19265</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">NAdam</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/a3l4txbf' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/a3l4txbf</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_175407-a3l4txbf\logs</code>

# %%
df = pandas.DataFrame(results)
df.insert(0, 'Name', df.pop('Name'))
display(df)
# Out:
#                 Name  Accuracy  TOP-2 Accuracy  TOP-3 Accuracy  \
# 0              AdamW    0.5373          0.7252          0.8243
# 1                SGD    0.5412          0.7369          0.8326
# 2  SGD with momentum    0.5410          0.7315          0.8337
# 3            Adagrad    0.5469          0.7362          0.8321
# 4               ASGD    0.5048          0.7018          0.8069
# 5              NAdam    0.5330          0.7242          0.8277
#
#    TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  TOP-7 Accuracy  \
# 0          0.8909          0.9311          0.9582          0.9765
# 1          0.8958          0.9335          0.9615          0.9774
# 2          0.8953          0.9354          0.9589          0.9772
# 3          0.8947          0.9328          0.9607          0.9794
# 4          0.8739          0.9198          0.9506          0.9729
# 5          0.8900          0.9294          0.9568          0.9757
#
#    TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  Recall  F1-score  \
# 0          0.9877          0.9957  0.892386   0.534711  0.5373  0.534164
# 1          0.9889          0.9962  0.897596   0.542735  0.5412  0.540684
# 2          0.9878          0.9955  0.896936   0.538720  0.5410  0.537976
# 3          0.9887          0.9961  0.897986   0.547304  0.5469  0.546290
# 4          0.9868          0.9950  0.880257   0.501108  0.5048  0.500047
# 5          0.9879          0.9962  0.891321   0.537141  0.5330  0.527993
#
#        Loss  Train time  Validation time
# 0  0.881930    5.429235         1.165746
# 1  1.068583    4.871344         1.062385
# 2  0.800014    4.963989         1.126486
# 3  0.920257    4.830807         1.062044
# 4  1.389153    4.983727         1.097097
# 5  0.786897    5.284339         1.208107

# %% [markdown]
# ![Alternative Text][1696863450942]
#
# Значительной разницы в рассмотренных алгоритмах оптимизации нет. Явно выделяются лишь `ASGD`, при использовании которого качество оказалось заметно хуже остальных, и `NAdam`, который показал себя достаточно странно на первых эпохах. Также интересно, что `AdaGrad` показал качество немного лучше остальных, хотя и не оптимизировал функцию потерь достаточно хорошо. По графикам видно, что такой пик качества - случайность нежели закономерность. С помощью других алгоритмов было получено примерно одинаковое качество около `54%`. Далее будем использовать `AdamW`, так как он достиг качества, близкого к максимальному, за наименьшее количество эпох, а также наиболее хорошо минимазировал значение лосс-функции.
#
# [1696863450942]:data:image/png;base64,...

# %% [markdown]
# # Ideas for extra work
#
# * Find optimal size of hidden layer ✅
# * Plot mean absolute gradients value per layer ✅
# * Compare different Activation functions ✅
# * Use instruments like [Tensorboard](https://pytorch.org/docs/stable/tensorboard.html) or [WandB](https://wandb.ai/site) to log results ✅
# * Use [Lightning](https://lightning.ai/) to implement train loop

# %% [markdown]
# ## Different Loss Functions

# %%
results = [ ]
def test_loss_function(criterion, name):
    set_random_seed(RANDOM_STATE)
    model = TwoLayerFCN(10).to(device)
    optimizer = torch.optim.AdamW(model.parameters())
    results.append(train(name, model, criterion, optimizer))

# %%
test_loss_function(torch.nn.CrossEntropyLoss(), "CrossEntropyLoss")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777781415, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_175651-kg9zr5ay</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/kg9zr5ay' target="_blank">CrossEntropyLoss</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/kg9zr5ay' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/kg9zr5ay</a>
# 100%|██████████| 25/25 [02:33<00:00,  6.15s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.019 MB of 0.019 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▄▅▆▆▆▇▇█▆▇███▇██▇▆▇▆▆▆▇▆</td></tr><tr><td>Accuracy</td><td>▁▄▄▅▅▇▇▇▇▆▅▇██▇▇▇▇▆▇▇▆▇▇▆</td></tr><tr><td>F1-score</td><td>▁▄▄▅▅▇▇▇▇▆▅███▇▇▇▇▇█▇▆▇▇▇</td></tr><tr><td>Loss</td><td>██▆▇▆▅▅▅▅▄▃▄▄▃▃▃▂▂▂▂▂▁▁▂▁</td></tr><tr><td>Precision</td><td>▁▄▅▅▆█▇▆▇▆▅▇███▇▇▇▇█▆▇▇▇█</td></tr><tr><td>Recall</td><td>▁▄▄▅▅▇▇▇▇▆▅▇██▇▇▇▇▆▇▇▆▇▇▆</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▄▅▆▆▆▇▇█▆▆███▇▇▇▇▆█▆▇▆▆▆</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▅▅▆▆▆▇▇█▆▆█▇█▇▇█▇▇▇▆▇▆▆▆</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▅▅▅▆▆▆▇▇▆▆███▇▇▇▇▇▇▆▇▆▇▆</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▅▆▆▆▇▇▇▆▆█▇▇▇▇▇▇▇▇▇▇▆▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▅▅▆▆▆▇▇▇▆▆███▇██▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▄▅▆▆▇▆▇▆▆█▇▇▇▇▇▇▆▇▇▇▆▇▆</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▄▅▆▆▆▆▇▅▅█▇█▆▇▇▇▆▇▆▆▆▇▅</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▄▅▅▅▇█▅█▆█▅▇▇█▆▅▇▅▇█▅▄▄▇</td></tr><tr><td>Train time</td><td>▅▇▅▃▄▄▆▃▃▂▂▁▁▂▃▂▂▃▅▄▄▄▅██</td></tr><tr><td>Validation time</td><td>▁▅█▂▆▆▂▆▅▃█▃▃▂▆▂▆▄▅▁▅▆▅▆▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88258</td></tr><tr><td>Accuracy</td><td>0.5204</td></tr><tr><td>F1-score</td><td>0.52342</td></tr><tr><td>Loss</td><td>0.42222</td></tr><tr><td>Precision</td><td>0.53654</td></tr><tr><td>Recall</td><td>0.5204</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7116</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8119</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8811</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9276</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9572</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9747</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9864</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9958</td></tr><tr><td>Train time</td><td>5.53372</td></tr><tr><td>Validation time</td><td>1.21822</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">CrossEntropyLoss</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/kg9zr5ay' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/kg9zr5ay</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_175651-kg9zr5ay\logs</code>

# %%
loss = torch.nn.MultiLabelMarginLoss()
def MultiLabelMarginLoss(output, labels):
    nul = torch.full((output.shape[0], 1), -1).to(device)
    labels = torch.cat([ labels.unsqueeze(1), nul, nul, nul, nul, nul, nul, nul, nul, nul ], dim = 1)
    return loss(output, labels)

test_loss_function(MultiLabelMarginLoss, "MultiLabelMarginLoss")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01128888888889479, max=1.0)…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_175930-xb8n3ble</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/xb8n3ble' target="_blank">MultiLabelMarginLoss</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/xb8n3ble' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/xb8n3ble</a>
# 100%|██████████| 25/25 [02:42<00:00,  6.52s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▅▅▆▇▆▇▆█▇▇▇██▇▇██▇██▇▇█▇</td></tr><tr><td>Accuracy</td><td>▁▄▄▅▅▆▇▅▆▆▇▆▇▇▆▇▇▇▇██▇▆█▆</td></tr><tr><td>F1-score</td><td>▁▄▄▅▅▆▇▅▇▆▇▆▇▇▇▇▇▇▇█▇▇▇█▇</td></tr><tr><td>Loss</td><td>██▅▆▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▁▂▁▁</td></tr><tr><td>Precision</td><td>▁▄▄▅▅▆▇▅▇▇▆▆█▇▇▇▇▇▇█▇███▇</td></tr><tr><td>Recall</td><td>▁▄▄▅▅▆▇▅▆▆▇▆▇▇▆▇▇▇▇██▇▆█▆</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▄▅▆▆▆▇▅▇▇▆▇██▇▇▇▇▇▇█▆▇█▆</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▅▅▆▆▇▇▅▇▇▇▇██▇▇█▇▇▇▇▆▆█▆</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▄▅▅▆▆▇▄▇█▆▇█▇▇▇█▆▇▇▇▆▆▇▇</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▅▅▆▆▇▅▇▇▆▇█▇▇▇█▆▇▇▇▆▆▆▆</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▄▅▆█▇▇▅▇▇▇▇▇██▇█▇█▇▇▇▇▇▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▅▆█▆█▅▇██▇█▇▇▇▇▇█▇▇▇▆▇▇</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▄▆▇▆█▄▇▆▇▇██▇▇█▇▆█▇▇▇▇▆</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▄▃▆▇▆█▆▆▆█▄▆▇▆█▆▆▅▆▆▇▅▆▅</td></tr><tr><td>Train time</td><td>▇▇▁▄▅▆▆█▄▅▅▇▇▇▄▅▃▂▂▁▇▃▅▆▅</td></tr><tr><td>Validation time</td><td>█▂▁▄▇▂▃▆▂▂▂▆▅▃▅▁▄▃▄▄▃▄▃▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88103</td></tr><tr><td>Accuracy</td><td>0.5098</td></tr><tr><td>F1-score</td><td>0.51131</td></tr><tr><td>Loss</td><td>0.07137</td></tr><tr><td>Precision</td><td>0.52459</td></tr><tr><td>Recall</td><td>0.5098</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7054</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8115</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8827</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9251</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9546</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9744</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9868</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9951</td></tr><tr><td>Train time</td><td>5.37986</td></tr><tr><td>Validation time</td><td>1.37105</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">MultiLabelMarginLoss</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/xb8n3ble' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/xb8n3ble</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_175930-xb8n3ble\logs</code>

# %%
softmax = torch.nn.LogSoftmax(dim = 1)
loss = torch.nn.NLLLoss()
def NLLLoss(output, labels):
    output = softmax(output)
    return loss(output, labels)

test_loss_function(NLLLoss, "NLLLoss")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.88258</td></tr><tr><td>Accuracy</td><td>0.5204</td></tr><tr><td>F1-score</td><td>0.52342</td></tr><tr><td>Loss</td><td>0.42222</td></tr><tr><td>Precision</td><td>0.53654</td></tr><tr><td>Recall</td><td>0.5204</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7116</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8119</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8811</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9276</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9572</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9747</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9864</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9958</td></tr><tr><td>Train time</td><td>4.81052</td></tr><tr><td>Validation time</td><td>1.22017</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">NLLLoss</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/ftgo04zu' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/ftgo04zu</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_180219-ftgo04zu\logs</code>

# %%
df = pandas.DataFrame(results)
df.insert(0, 'Name', df.pop('Name'))
display(df)
# Out:
#                    Name  Accuracy  TOP-2 Accuracy  TOP-3 Accuracy  \
# 0      CrossEntropyLoss    0.5373          0.7252          0.8243
# 1  MultiLabelMarginLoss    0.5271          0.7216          0.8223
# 2               NLLLoss    0.5373          0.7252          0.8243
#
#    TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  TOP-7 Accuracy  \
# 0          0.8909          0.9311          0.9582          0.9765
# 1          0.8856          0.9248          0.9548          0.9742
# 2          0.8909          0.9311          0.9582          0.9765
#
#    TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  Recall  F1-score  \
# 0          0.9877          0.9957  0.892386   0.534711  0.5373  0.534164
# 1          0.9879          0.9960  0.885240   0.528610  0.5271  0.525587
# 2          0.9877          0.9957  0.892386   0.534711  0.5373  0.534164
#
#        Loss  Train time  Validation time
# 0  0.881930    4.614264         1.086522
# 1  0.063972    5.474464         1.133293
# 2  0.881930    5.151367         1.272425

# %% [markdown]
# ![Alternative Text][1696863949297]
#
# Изменение лосс-функции также не дало значительного повышения качества. Заметим, что поведение `NLLoss` полностью совпадает с `CrossEntropyLoss`. Действительно, `CrossEntropyLoss` является ничем иным, как последовательным применением `LogSoftmax` и `CrossEntropyLoss`. Для дальнейшего анализа будем использовать `CrossEntropyLoss`, который показал себя чуть лучше `MultiLabelMarginLoss` и не требует явного добавления `LogSoftmax`
#
# [1696863949297]:data:image/png;base64,...

# %% [markdown]
# ## Different net architecture

# %% [markdown]
# ### Batch normalization
#
# ![Alternative Text][1696864007520]
#
# На графиках видно, что градиент `bias` последнего слоя выглядит достаточно странно: явно смещён от нуля. В такой ситуации должно помочь добавление нормализации в скрытый слой.
#
# [1696864007520]:data:image/png;base64,...

# %%
def test_net_arch(model, name):
    model = model.to(device)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.AdamW(model.parameters())
    return train(name, model, criterion, optimizer)

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 500),
    torch.nn.BatchNorm1d(500), # Added
    torch.nn.ReLU(),
    torch.nn.Linear(500, 10)
)
test_net_arch(model, "BatchNorm")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89665</td></tr><tr><td>Accuracy</td><td>0.5423</td></tr><tr><td>F1-score</td><td>0.5416</td></tr><tr><td>Loss</td><td>0.56999</td></tr><tr><td>Precision</td><td>0.54308</td></tr><tr><td>Recall</td><td>0.5423</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7317</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8343</td></tr><tr><td>TOP-4 Accuracy</td><td>0.898</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9378</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9618</td></tr><tr><td>TOP-7 Accuracy</td><td>0.979</td></tr><tr><td>TOP-8 Accuracy</td><td>0.99</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9971</td></tr><tr><td>Train time</td><td>4.97486</td></tr><tr><td>Validation time</td><td>1.23285</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">BatchNorm</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/x9om7glx' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/x9om7glx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_180501-x9om7glx\logs</code>
# {'Accuracy': 0.551,
#  'TOP-2 Accuracy': 0.7428,
#  'TOP-3 Accuracy': 0.8414,
#  'TOP-4 Accuracy': 0.9019,
#  'TOP-5 Accuracy': 0.9392,
#  'TOP-6 Accuracy': 0.9637,
#  'TOP-7 Accuracy': 0.9803,
#  'TOP-8 Accuracy': 0.9891,
#  'TOP-9 Accuracy': 0.9972,
#  'AUC-ROC': 0.9008280555555555,
#  'Precision': 0.5500509266752514,
#  'Recall': 0.5509999999999999,
#  'F1-score': 0.5495185866445804,
#  'Loss': 0.866258442401886,
#  'Train time': 4.916605700000218,
#  'Validation time': 1.168615900000077,
#  'Name': 'BatchNorm'}

# %% [markdown]
# ![Alternative Text][1696864096329]
#
# ![Alternative Text][1696864111809]
#
# Действительно, добавление нормализации помогло: качество немного увеличилось, а градиенты полносвязных слоев выглядят лучше
#
# [1696864096329]:data:image/png;base64,...
#
# [1696864111809]:data:image/png;base64,...

# %% [markdown]
# ### Different activation functions

# %%
results = [ ]
def test_activation_function(module, name):
    set_random_seed(RANDOM_STATE)
    model = torch.nn.Sequential(
        torch.nn.Flatten(),
        torch.nn.Linear(3072, 500),
        torch.nn.BatchNorm1d(500),
        module,
        torch.nn.Linear(500, 10)
    )
    results.append(test_net_arch(model, name))

# %%
test_activation_function(torch.nn.ReLU(), "ReLU")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_180742-k33triv7</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/k33triv7' target="_blank">ReLU</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/k33triv7' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/k33triv7</a>
# 100%|██████████| 25/25 [02:34<00:00,  6.19s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.8969</td></tr><tr><td>Accuracy</td><td>0.5352</td></tr><tr><td>F1-score</td><td>0.53267</td></tr><tr><td>Loss</td><td>0.90317</td></tr><tr><td>Precision</td><td>0.53179</td></tr><tr><td>Recall</td><td>0.5352</td></tr><tr><td>TOP-2 Accuracy</td><td>0.734</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8345</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8974</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9353</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9592</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9768</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9887</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9967</td></tr><tr><td>Train time</td><td>5.37522</td></tr><tr><td>Validation time</td><td>1.16457</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ELU</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/pijt1ie4' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/pijt1ie4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_181024-pijt1ie4\logs</code>

# %%
test_activation_function(torch.nn.LeakyReLU(), "LeakyReLU")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_181305-tmnm853e</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/tmnm853e' target="_blank">LeakyReLU</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/tmnm853e' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/tmnm853e</a>
# 100%|██████████| 25/25 [02:39<00:00,  6.37s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.026 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050400…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▃▅▆▇▇▇▇███▇██████▇▇███▇█</td></tr><tr><td>Accuracy</td><td>▁▃▅▅▆▇▇▇▇▇▇▇▇█████▇██▇███</td></tr><tr><td>F1-score</td><td>▁▃▅▅▆▇▆▇▇▇▇▇▇█████▇██▇███</td></tr><tr><td>Loss</td><td>██▆▇▆▅▄▅▅▄▃▄▄▃▃▂▃▂▂▂▂▁▁▁▁</td></tr><tr><td>Precision</td><td>▁▃▅▅▆▆▆▆▇▇▆▇▇████▇▇██▇███</td></tr><tr><td>Recall</td><td>▁▃▅▅▆▇▇▇▇▇▇▇▇█████▇██▇███</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▅▆▇▇▇▇▇▇▇▇▇██▇██▆▇█▇██▇</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▅▅▆▆▆▆▇▇▇▆▇██▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▃▅▅▆▆▆▆▇▇▇▇▇█▇▇█▇▇▇█▇▇▇█</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▅▅▆▇▆▆█▇▇▇▇▇▇▇██▇▇█▇█▇█</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▄▄▅▆▇▆▆▇▇▇▇▆▇▆▇▇▇▆▇▇▇▇▇█</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▅▆▇▇▇▇▇▇▇▇▇▇▇▇██▇▇▇▇▇▆█</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▃▄▆▇▇▇██▇▇▇▇▆▆█▇█▆▇▇▇▇▇▆</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▅▆▆███▇█▇▇▅▆▇▆▆▆▆▆▇▆▆█▆▆</td></tr><tr><td>Train time</td><td>▅█▄▅▂▂▄▄▃▃▂▅▇▅█▅▁▃▆▆▇▂▃▄▃</td></tr><tr><td>Validation time</td><td>▄▅▂▃▄█▁▂▅▂▃▂▁▇▂▅▂▁▅▆▂▁▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89848</td></tr><tr><td>Accuracy</td><td>0.5469</td></tr><tr><td>F1-score</td><td>0.54653</td></tr><tr><td>Loss</td><td>0.59372</td></tr><tr><td>Precision</td><td>0.54877</td></tr><tr><td>Recall</td><td>0.5469</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7374</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8399</td></tr><tr><td>TOP-4 Accuracy</td><td>0.9</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9397</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9658</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9799</td></tr><tr><td>TOP-8 Accuracy</td><td>0.988</td></tr><tr><td>TOP-9 Accuracy</td><td>0.996</td></tr><tr><td>Train time</td><td>5.02369</td></tr><tr><td>Validation time</td><td>1.19852</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">LeakyReLU</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/tmnm853e' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/tmnm853e</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_181305-tmnm853e\logs</code>

# %%
test_activation_function(torch.nn.PReLU(), "PReLU")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01127777777777131, max=1.0)…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_181550-bezsngdb</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/bezsngdb' target="_blank">PReLU</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/bezsngdb' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/bezsngdb</a>
# 100%|██████████| 25/25 [02:33<00:00,  6.13s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▃▅▆▇▇████████▇██▇▇▇▇▇▇▇▇</td></tr><tr><td>Accuracy</td><td>▁▃▅▆▆▇▇▇▇███▇█▇███▇▇▇▇▇▇▇</td></tr><tr><td>F1-score</td><td>▁▃▅▆▆▇▇▇▇███▇█▇███▇▇█▇▇▇▇</td></tr><tr><td>Loss</td><td>██▇▇▆▅▅▅▅▄▄▄▄▃▃▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>Precision</td><td>▁▃▅▆▆▇▇█▇█████▇██████▇▇▇▇</td></tr><tr><td>Recall</td><td>▁▃▅▆▆▇▇▇▇███▇█▇███▇▇▇▇▇▇▇</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▅▆▇▇████████▇█▇▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▅▆▇▇█▇███▇██▇█▇█▇▇▇▇▇▇▇</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▃▅▆▇▇█▇▇▇█▇▇█▇███▇▇▇▇▇▇▇</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▆▆▇▇▇▇▇▇█▇▇█▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▄▆▆▇▇█▇▇▇██▇██████▇▇▇▇█▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▅▆▇▇█▇▇▇▇█▇█▇▇▇▇▇▇▇▇▆▇▇</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▃▅▆█▇██▇▇▇█▆▇▇▇▆▇▇▇▇▇▇▇▇</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▄▅▆█▇█▆▆▆▇▆▆▆▇▇▅▇▆▆▅▆▆▆▅</td></tr><tr><td>Train time</td><td>▅▅▄▆▄▃▄▅▅▄▄▄▃▄█▁▁▂▃▄▂▂▂▂▅</td></tr><tr><td>Validation time</td><td>▄▄▅▄▆▆▄▇▂▇▇▄▆▆█▄▂▁▆▃▆▅▅▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89229</td></tr><tr><td>Accuracy</td><td>0.5361</td></tr><tr><td>F1-score</td><td>0.53701</td></tr><tr><td>Loss</td><td>0.34972</td></tr><tr><td>Precision</td><td>0.54067</td></tr><tr><td>Recall</td><td>0.5361</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7238</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8276</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8933</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9335</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9598</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9767</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9878</td></tr><tr><td>TOP-9 Accuracy</td><td>0.995</td></tr><tr><td>Train time</td><td>5.14309</td></tr><tr><td>Validation time</td><td>1.16096</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">PReLU</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/bezsngdb' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/bezsngdb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_181550-bezsngdb\logs</code>

# %%
test_activation_function(torch.nn.RReLU(), "RReLU")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777781415, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_181830-p2jowi94</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/p2jowi94' target="_blank">RReLU</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89391</td></tr><tr><td>Accuracy</td><td>0.528</td></tr><tr><td>F1-score</td><td>0.52605</td></tr><tr><td>Loss</td><td>1.00782</td></tr><tr><td>Precision</td><td>0.52597</td></tr><tr><td>Recall</td><td>0.528</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7254</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8277</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8899</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9309</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9575</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9761</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9883</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9955</td></tr><tr><td>Train time</td><td>5.03415</td></tr><tr><td>Validation time</td><td>1.09961</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">SELU</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/9pav6mdg' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/9pav6mdg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_182106-9pav6mdg\logs</code>

# %%
test_activation_function(torch.nn.GELU(), "GELU")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888884685, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_182344-9pj9szvf</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/9pj9szvf' target="_blank">GELU</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/9pj9szvf' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/9pj9szvf</a>
# 100%|██████████| 25/25 [02:25<00:00,  5.83s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.026 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050525…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▄▆▆▇▇▇███▇▇██████▆▇▇▇▇▇▇</td></tr><tr><td>Accuracy</td><td>▁▃▅▅▆▇▇▇▇▇▇▆██▇▇█▇▆▇▇▇▇▇▇</td></tr><tr><td>F1-score</td><td>▁▃▅▅▆▇▇▇▇▇▇▆██▇▇█▇▇▇▇▇▇▇▇</td></tr><tr><td>Loss</td><td>██▆▇▆▅▅▅▅▄▄▄▄▄▄▂▃▂▂▂▂▁▁▁▁</td></tr><tr><td>Precision</td><td>▁▃▅▅▆▆▆▇▇▇▆▆▇█▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>Recall</td><td>▁▃▅▅▆▇▇▇▇▇▇▆██▇▇█▇▆▇▇▇▇▇▇</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▃▆▆▇▇▇█▇▇▇▇▇█████▆▇█▇▇▇▇</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▃▅▅▇▇▇▇▇▇▇▇▇█████▆██▇▇▇▇</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▄▅▅▇▇▇▇▇▇▇▇██████▇██▇█▇█</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▅▅▆▇▆▇▇▇▇▇▇██▇██▇▇█▇▇▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▄▅▆▇▇▇▇▇██▇▇█▇█▇█▇██▇▇▇█</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▅▆▇▇▇▇▇███▇█▇███▇███▇▇█</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▅▆▇███▇▇▇▇█▇▇█▇█▇▇▇▆▇▇█</td></tr><tr><td>TOP-9 Accuracy</td><td>▁▅▅▆▇▇▇▇█▅▇▄▇▆▆▆▅▆▅▇▇▆▆▅▆</td></tr><tr><td>Train time</td><td>█▄▃▂▃▂▁▃▁▃▁▂▁▃▂▄▁▃▁▂▁▂▂▃▂</td></tr><tr><td>Validation time</td><td>▇▄▆▇▄▃▁█▃▄▄▄▄▃▃▁▄▆▆▄▇▄▄▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89576</td></tr><tr><td>Accuracy</td><td>0.5427</td></tr><tr><td>F1-score</td><td>0.54344</td></tr><tr><td>Loss</td><td>0.4988</td></tr><tr><td>Precision</td><td>0.54749</td></tr><tr><td>Recall</td><td>0.5427</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7334</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8363</td></tr><tr><td>TOP-4 Accuracy</td><td>0.9002</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9382</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9646</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9797</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9899</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9965</td></tr><tr><td>Train time</td><td>4.63027</td></tr><tr><td>Validation time</td><td>1.11857</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">GELU</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/9pj9szvf' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/9pj9szvf</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_182344-9pj9szvf\logs</code>

# %%
test_activation_function(torch.nn.Sigmoid(), "Sigmoid")
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888884685, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_182615-j624iboo</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/j624iboo' target="_blank">Sigmoid</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/j624iboo' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/j624iboo</a>
# 100%|██████████| 25/25 [02:24<00:00,  5.78s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td
td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Sigmoid</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/j624iboo' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/j624iboo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_182615-j624iboo\logs</code>

# %%
df = pandas.DataFrame(results)
df.insert(0, 'Name', df.pop('Name'))
display(df)
# Out:
#         Name  Accuracy  TOP-2 Accuracy  TOP-3 Accuracy  TOP-4 Accuracy  \
# 0       ReLU    0.5510          0.7428          0.8414          0.9019
# 1        ELU    0.5402          0.7358          0.8390          0.9001
# 2  LeakyReLU    0.5488          0.7391          0.8450          0.8993
# 3      PReLU    0.5532          0.7443          0.8409          0.9015
# 4      RReLU    0.5422          0.7394          0.8410          0.9002
# 5       SELU    0.5280          0.7285          0.8344          0.8950
# 6       GELU    0.5554          0.7434          0.8427          0.9018
# 7    Sigmoid    0.4985          0.6864          0.7908          0.8557
#
#    TOP-5 Accuracy  TOP-6 Accuracy  TOP-7 Accuracy  TOP-8 Accuracy  \
# 0          0.9392          0.9637          0.9803          0.9891
# 1          0.9396          0.9627          0.9784          0.9902
# 2          0.9354          0.9602          0.9768          0.9880
# 3          0.9407          0.9634          0.9797          0.9891
# 4          0.9382          0.9635          0.9788          0.9885
# 5          0.9364          0.9625          0.9787          0.9889
# 6          0.9424          0.9638          0.9797          0.9894
# 7          0.9071          0.9408          0.9628          0.9789
#
#    TOP-9 Accuracy   AUC-ROC  Precision  Recall  F1-score      Loss  \
# 0          0.9972  0.900828   0.550051  0.5510  0.549519  0.866258
# 1          0.9969  0.899138   0.537153  0.5402  0.537750  0.901987
# 2          0.9959  0.899550   0.547047  0.5488  0.547118  0.866516
# 3          0.9960  0.901217   0.553331  0.5532  0.552391  0.775446
# 4          0.9971  0.899262   0.537566  0.5422  0.538493  0.826001
# 5          0.9962  0.895732   0.523401  0.5280  0.524520  0.999346
# 6          0.9965  0.901811   0.556716  0.5554  0.553368  0.856640
# 7          0.9928  0.873190   0.497715  0.4985  0.496716  1.245725
#
#    Train time  Validation time
# 0    5.419286         1.064092
# 1    4.987110         1.142848
# 2    5.436429         1.118276
# 3    4.996321         1.163992
# 4    4.911989         1.159076
# 5    5.094575         1.163016
# 6    4.766271         1.023747
# 7    4.730120         0.968424

# %% [markdown]
# ![Alternative Text][1696865384505]
#
# Видно, что сигмоида, ожидаемо, показывает себя сильно хуже остальные, а `SELU` - немного хуже. Далее будем использовать `GELU`, так как модель с именно этой функцией активации достигла наибольшего лучшего качества
#
# [1696865384505]:data:image/png;base64,...

# %% [markdown]
# ### Different hidden layer size

# %%
results = [ ]

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 500),
    torch.nn.BatchNorm1d(500),
    torch.nn.GELU(),
    torch.nn.Linear(500, 10)
)
results.append(test_net_arch(model, "500 hidden neurons"))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01128888888889479, max=1.0)…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_182847-gsul8mx4</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/gsul8mx4' target="_blank">500 hidden neurons</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai
9002</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9382</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9646</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9797</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9899</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9965</td></tr><tr><td>Train time</td><td>4.80426</td></tr><tr><td>Validation time</td><td>1.10923</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">500 hidden neurons</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/gsul8mx4' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/gsul8mx4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_182847-gsul8mx4\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 2000),
    torch.nn.BatchNorm1d(2000),
    torch.nn.GELU(),
    torch.nn.Linear(2000, 10)
)
results.append(test_net_arch(model, "2000 hidden neurons"))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888884685, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_183127-ku73dt39</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/ku73dt39' target="_blank">2000 hidden neurons</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/ku73dt39' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/ku73dt39</a>
# 100%|██████████| 25/25 [02:27<00:00,  5.91s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.003 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.523827…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▄▅▆▇▇▇██████▇▇███▇▇█▇▇▇▆</td></tr><tr><td>Accuracy</td><td>▁▃▄▆▆▇▆▇▇▇▇██▇▇████▇███▇▇</td></tr><tr><td>F1-score</td><td>▁▃▄▆▆▆▆▇▇▇▇▇█▇▇████▇█▇█▇▇</td></tr><tr><td>Loss</td><td>█▇▇▆▆▆▆▅▅▅▄▄▃▄▄▃▂▂▂▂▁▁▂▁▁</td></tr><tr><td>Precision</td><td>▁▃▄▅▆▆▆▇▇▇▇▇█▇▇█▇▇█▇█▇█▇█</td></tr><tr><td>Recall</td><td>▁▃▄▆▆▇▆▇▇▇▇██▇▇████▇███▇▇</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▄▅▆▇▇▇██████▇▇████▇█▇█▇▇</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▄▄▆▇▆▇▇█▇▇▇█▇▇██▇▇▇█▇▇▇▆</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▄▄▆▇▇▇▇█▇▇▇█▇▇▇██▇▇█▇▇▇▆</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▄▆▇▇▇▇██▇██▇█████▇█▆▇▇▇</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▄▄▆▇▆▇▆▇█▇██▇▇▇▇▇█▇█▇▇▇▇</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▄▃▅▇▆▇▇▇▇▇██▇▇▇▇▇█▇█▆▇▇▆</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▄▃▆▆▆▆██▇▇▇█▆▇▇▇▆███▅▇▇▆</td></tr><tr><td>TOP-9 Accuracy</td><td>▂▄▁▆▄▂▅▆▆▆▃▆▇█▄██▇▇▇▆▃▅▇▄</td></tr><tr><td>Train time</td><td>▇▇▄▅▅▃▇▆▅▄▅▆▅▆▇▅█▇▁▃▅█▆▆▆</td></tr><tr><td>Validation time</td><td>▄▃▅▄▂▁▃▄▄▃▃▃▄▅▄▃▁▃▄▂█▅▃▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89073</td></tr><tr><td>Accuracy</td><td>0.5392</td></tr><tr><td>F1-score</td><td>0.54163</td></tr><tr><td>Loss</td><td>0.36586</td></tr><tr><td>Precision</td><td>0.55287</td></tr><tr><td>Recall</td><td>0.5392</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7261</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8257</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8881</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9334</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9593</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9769</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9877</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9957</td></tr><tr><td>Train time</td><td>4.80065</td></tr><tr><td>Validation time</td><td>1.131</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">2000 hidden neurons</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/ku73dt39' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/ku73dt39</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_183127-ku73dt39\logs</code>

# %%
df = pandas.DataFrame(results)
df.insert(0, 'Name', df.pop('Name'))
display(df)
# Out:
#                   Name  Accuracy  TOP-2 Accuracy  TOP-3 Accuracy  \
# 0   500 hidden neurons    0.5554          0.7434          0.8427
# 1  2000 hidden neurons    0.5500          0.7396          0.8404
#
#    TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  TOP-7 Accuracy  \
# 0          0.9018          0.9424          0.9638          0.9797
# 1          0.9018          0.9387          0.9643          0.9798
#
#    TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  Recall  F1-score  \
# 0          0.9894          0.9965  0.901811   0.556716  0.5554  0.553368
# 1          0.9903          0.9968  0.897813   0.555945  0.5500  0.552265
#
#        Loss  Train time  Validation time
# 0  0.856640    4.588503         1.157999
# 1  0.519094    4.470274         1.159346

# %% [markdown]
# ![Alternative Text][1696865705097]
#
# Добавление нейронов в скрытый слой прироста к качеству не дало, а, напротив, снизило его: скорее всего, модель быстро переобучилась. Также интересно, что и время обучения не увеличилось.
#
# [1696865705097]:data:image/png;base64,...

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 500),
    torch.nn.BatchNorm1d(500),
    torch.nn.GELU(),
    torch.nn.Linear(500, 250),
    torch.nn.BatchNorm1d(250),
    torch.nn.GELU(),
    torch.nn.Linear(250, 10)
)
results.append(test_net_arch(model, "500 + 250 hidden neurons"))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.89897</td></tr><tr><td>Accuracy</td><td>0.5556</td></tr><tr><td>F1-score</td><td>0.55224</td></tr><tr><td>Loss</td><td>0.13415</td></tr><tr><td>Precision</td><td>0.55451</td></tr><tr><td>Recall</td><td>0.5556</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7426</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8384</td></tr><tr><td>TOP-4 Accuracy</td><td>0.8978</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9372</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9614</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9785</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9881</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9949</td></tr><tr><td>Train time</td><td>4.67274</td></tr><tr><td>Validation time</td><td>1.11966</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">500 + 250 hidden neurons</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/db9vxrs0' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/db9vxrs0</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_183401-db9vxrs0\logs</code>

# %% [markdown]
# Добавление слоя в сеть немного увеличило качество. Попробуем добавить ещё слои, чтобы достичь наибольшего качества

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 1500),
    torch.nn.BatchNorm1d(1500),
    torch.nn.GELU(),
    torch.nn.Linear(1500, 500),
    torch.nn.BatchNorm1d(500),
    torch.nn.GELU(),
    torch.nn.Linear(500, 250),
    torch.nn.BatchNorm1d(250),
    torch.nn.GELU(),
    torch.nn.Linear(250, 10)
)
results.append(test_net_arch(model, "1500 + 500 + 250 hidden neurons"))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_183638-zlbc3dbd</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/zlbc3dbd' target="_blank">1500 + 500 + 250 hidden neurons</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/zlbc3dbd' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/zlbc3dbd</a>
# 100%|██████████| 25/25 [02:35<00:00,  6.24s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▅▆▆▇███▇▇█▇▇▇▆▆▇▇▇▇▇▆▇▇▇</td></tr><tr><td>Accuracy</td><td>▁▅▅▅▆▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇▇█</td></tr><tr><td>F1-score</td><td>▁▄▄▅▆▇▆▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇██</td></tr><tr><td>Loss</td><td>█▇█▇▇▆▆▅▅▄▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>Precision</td><td>▁▄▄▅▆▇▆▇▇▆▇▇▇▇▇▇█▇█▇█▇▇██</td></tr><tr><td>Recall</td><td>▁▅▅▅▆▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇▇█</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▅▆▆▆▇█▇▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▅▆▆▇▇█▇▇▆█▇▇▇▆▇▇▇▇▇▇▆▆▇▇</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▆▆▇██▇▇▇█▇█▇▆▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▅▆▆▇▇▇█▇▆██▇█▇▇▇▆▇▇█▆▇▇█</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▅▄▆▆█▇█▇▆█▇▆▇▇▇▆▆▆▆▆▅▆▇▇</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▆▄▅▆▇▆█▇▆█▆▅▆▅▆▆▄▅▅▅▄▅▆▅</td></tr><tr><td>TOP-9 Accuracy</td><td>▃▄▅▄▇▆▅█▆▄▇▆▅▇▃▅▅▁▄▇▃▃▃▃▃</td></tr><tr><td>Train time</td><td>█▁▃▃▄▁▅▃▆▅▅▆▆▆▆▅▆▅▆▇▆▇▆▆▆</td></tr><tr><td>Validation time</td><td>█▁▄▂▄▂▁▅▆▅▅▆▇▅▄▃▅▆▆▆▄▆▆▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.90523</td></tr><tr><td>Accuracy</td><td>0.5778</td></tr><tr><td>F1-score</td><td>0.57809</td></tr><tr><td>Loss</td><td>0.07883</td></tr><tr><td>Precision</td><td>0.57927</td></tr><tr><td>Recall</td><td>0.5778</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7653</td></tr><tr><td>TOP-3 Accuracy</td><td>0.855</td></tr><tr><td>TOP-4 Accuracy</td><td>0.9088</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9444</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9667</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9804</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9889</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9956</td></tr><tr><td>Train time</td><td>5.06326</td></tr><tr><td>Validation time</td><td>1.22092</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">1500 + 500 + 250 hidden neurons</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/zlbc3dbd' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/zlbc3dbd</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_183638-zlbc3dbd\logs</code>

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 1500),
    torch.nn.BatchNorm1d(1500),
    torch.nn.GELU(),
    torch.nn.Linear(1500, 800),
    torch.nn.BatchNorm1d(800),
    torch.nn.GELU(),
    torch.nn.Linear(800, 500),
    torch.nn.BatchNorm1d(500),
    torch.nn.GELU(),
    torch.nn.Linear(500, 250),
    torch.nn.BatchNorm1d(250),
    torch.nn.GELU(),
    torch.nn.Linear(250, 10)
)
results.append(test_net_arch(model, "1500 + 800 + 500 + 250 hidden neurons"))
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0
�</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.90069</td></tr><tr><td>Accuracy</td><td>0.5657</td></tr><tr><td>F1-score</td><td>0.56665</td></tr><tr><td>Loss</td><td>0.06237</td></tr><tr><td>Precision</td><td>0.56923</td></tr><tr><td>Recall</td><td>0.5657</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7489</td></tr><tr><td>TOP-3 Accuracy</td><td>0.8476</td></tr><tr><td>TOP-4 Accuracy</td><td>0.9037</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9408</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9654</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9796</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9889</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9954</td></tr><tr><td>Train time</td><td>4.804</td></tr><tr><td>Validation time</td><td>1.16342</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">1500 + 800 + 500 + 250 hidden neurons</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/9stw4v6w' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/9stw4v6w</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_183922-9stw4v6w\logs</code>

# %%
df = pandas.DataFrame(results)
df.insert(0, 'Name', df.pop('Name'))
display(df)
# Out:
#                                     Name  Accuracy  TOP-2 Accuracy  \
# 0                     500 hidden neurons    0.5554          0.7434
# 1                    2000 hidden neurons    0.5500          0.7396
# 2               500 + 250 hidden neurons    0.5603          0.7559
# 3        1500 + 500 + 250 hidden neurons    0.5778          0.7653
# 4  1500 + 800 + 500 + 250 hidden neurons    0.5721          0.7566
#
#    TOP-3 Accuracy  TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  \
# 0          0.8427          0.9018          0.9424          0.9638
# 1          0.8404          0.9018          0.9387          0.9643
# 2          0.8527          0.9098          0.9432          0.9675
# 3          0.8550          0.9088          0.9444          0.9667
# 4          0.8439          0.9013          0.9392          0.9632
#
#    TOP-7 Accuracy  TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  \
# 0          0.9797          0.9894          0.9965  0.901811   0.556716
# 1          0.9798          0.9903          0.9968  0.897813   0.555945
# 2          0.9805          0.9907          0.9970  0.908935   0.563616
# 3          0.9804          0.9889          0.9956  0.905233   0.579274
# 4          0.9788          0.9895          0.9954  0.900470   0.576448
#
#    Recall  F1-score      Loss  Train time  Validation time
# 0  0.5554  0.553368  0.856640    4.588503         1.157999
# 1  0.5500  0.552265  0.519094    4.470274         1.159346
# 2  0.5603  0.558344  0.796975    5.177054         1.034514
# 3  0.5778  0.578091  0.078826    5.063260         1.220916
# 4  0.5721  0.573470  0.135336    5.874913         1.290381

# %% [markdown]
# ![Alternative Text][1696866182394]
#
# Добавление 3 слоя привело к улучшению модели, но 4 слой не оказал значительного влияния на качество и даже немного его понизил. Следовательно, остановимся на 3 слоях.
#
# ![Alternative Text][1696866258330]
# ![Alternative Text][1696866266130]
# ![Alternative Text][1696866273210]
#
# Градиенты параметров модели, состоящей из 3-х слоев, также выглядят хорошо.
#
# [1696866182394]:data:image/png;base64,...
#
# [1696866258330]:data:image/png;base64,...
#
# [1696866266130]:data:image/png;base64,...
#
# [1696866273210]:data:image/png;base64,...

# %% [markdown]
# # Итоговая модель

# %%
set_random_seed(RANDOM_STATE)
model = torch.nn.Sequential(
    torch.nn.Flatten(),
    torch.nn.Linear(3072, 1500),
    torch.nn.BatchNorm1d(1500),
    torch.nn.GELU(),
    torch.nn.Linear(1500, 500),
    torch.nn.BatchNorm1d(500),
    torch.nn.GELU(),
    torch.nn.Linear(500, 250),
    torch.nn.BatchNorm1d(250),
    torch.nn.GELU(),
    torch.nn.Linear(250, 10)
).to(device)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters())
train("FINAL MODEL", model, criterion, optimizer)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01128888888889479, max=1.0)…
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>d:\HSE\year-3\HSE-ML\computer-vision\HW3\wandb\run-20231009_184211-47zbjnfg</code>
# Syncing run <strong><a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/47zbjnfg' target="_blank">FINAL MODEL</a></strong> to <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/hse-iad/NIS-HW-3' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3</a>
#  View run at <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/47zbjnfg' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/47zbjnfg</a>
# 100%|██████████| 25/25 [02:32<00:00,  6.09s/it]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>▁▅▆▆▇███▇▇█▇▇▇▆▆▇▇▇▇▇▆▇▇▇</td></tr><tr><td>Accuracy</td><td>▁▅▅▅▆▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇▇█</td></tr><tr><td>F1-score</td><td>▁▄▄▅▆▇▆▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇██</td></tr><tr><td>Loss</td><td>█▇█▇▇▆▆▅▅▄▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>Precision</td><td>▁▄▄▅▆▇▆▇▇▆▇▇▇▇▇▇█▇█▇█▇▇██</td></tr><tr><td>Recall</td><td>▁▅▅▅▆▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇▇▇█</td></tr><tr><td>TOP-2 Accuracy</td><td>▁▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-3 Accuracy</td><td>▁▅▆▆▆▇█▇▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-4 Accuracy</td><td>▁▅▆▆▇▇█▇▇▆█▇▇▇▆▇▇▇▇▇▇▆▆▇▇</td></tr><tr><td>TOP-5 Accuracy</td><td>▁▄▆▆▇██▇▇▇█▇█▇▆▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>TOP-6 Accuracy</td><td>▁▅▆▆▇▇▇█▇▆██▇█▇▇▇▆▇▇█▆▇▇█</td></tr><tr><td>TOP-7 Accuracy</td><td>▁▅▄▆▆█▇█▇▆█▇▆▇▇▇▆▆▆▆▆▅▆▇▇</td></tr><tr><td>TOP-8 Accuracy</td><td>▁▆▄▅▆▇▆█▇▆█▆▅▆▅▆▆▄▅▅▅▄▅▆▅</td></tr><tr><td>TOP-9 Accuracy</td><td>▃▄▅▄▇▆▅█▆▄▇▆▅▇▃▅▅▁▄▇▃▃▃▃▃</td></tr><tr><td>Train time</td><td>▃▁▄▃▄▃█▃▆▃▆▂▁▄▁▆▁▆▃▆▅▄▄▂▃</td></tr><tr><td>Validation time</td><td>▇▄▇▅█▄▅▃▂▇▄▆▄▄▅▃▂▅▅▁█▇▂▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC-ROC</td><td>0.90523</td></tr><tr><td>Accuracy</td><td>0.5778</td></tr><tr><td>F1-score</td><td>0.57809</td></tr><tr><td>Loss</td><td>0.07883</td></tr><tr><td>Precision</td><td>0.57927</td></tr><tr><td>Recall</td><td>0.5778</td></tr><tr><td>TOP-2 Accuracy</td><td>0.7653</td></tr><tr><td>TOP-3 Accuracy</td><td>0.855</td></tr><tr><td>TOP-4 Accuracy</td><td>0.9088</td></tr><tr><td>TOP-5 Accuracy</td><td>0.9444</td></tr><tr><td>TOP-6 Accuracy</td><td>0.9667</td></tr><tr><td>TOP-7 Accuracy</td><td>0.9804</td></tr><tr><td>TOP-8 Accuracy</td><td>0.9889</td></tr><tr><td>TOP-9 Accuracy</td><td>0.9956</td></tr><tr><td>Train time</td><td>4.85703</td></tr><tr><td>Validation time</td><td>1.21422</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">FINAL MODEL</strong> at: <a href='https://wandb.ai/hse-iad/NIS-HW-3/runs/47zbjnfg' target="_blank">https://wandb.ai/hse-iad/NIS-HW-3/runs/47zbjnfg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231009_184211-47zbjnfg\logs</code>
# {'Accuracy': 0.5778,
#  'TOP-2 Accuracy': 0.7653,
#  'TOP-3 Accuracy': 0.855,
#  'TOP-4 Accuracy': 0.9088,
#  'TOP-5 Accuracy': 0.9444,
#  'TOP-6 Accuracy': 0.9667,
#  'TOP-7 Accuracy': 0.9804,
#  'TOP-8 Accuracy': 0.9889,
#  'TOP-9 Accuracy': 0.9956,
#  'AUC-ROC': 0.9052327722222222,
#  'Precision': 0.5792738481730544,
#  'Recall': 0.5778,
#  'F1-score': 0.5780906920276,
#  'Loss': 0.07882624119520187,
#  'Train time': 4.857028399999763,
#  'Validation time': 1.2142238000005818,
#  'Name': 'FINAL MODEL'}

# %%
print('Accuracy: {}%'.format(validate(model.to('cpu'), test_loader) * 100))

model.eval()
with torch.no_grad():
    y_predicted = numpy.array([])
    y_true = numpy.array([])
    scores = numpy.empty((0, 10))
    for images, labels in test_loader:
        outputs = torch.nn.Softmax(dim = 1)(model(images))
        predicted = torch.argmax(outputs, dim = 1)

        y_predicted = numpy.append(y_predicted, predicted.cpu().detach().numpy())
        y_true = numpy.append(y_true, labels.cpu().detach().numpy())
        scores = numpy.concatenate([ scores, outputs.cpu().detach().numpy() ])

    print('TOP-1 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 1)))
    print('TOP-2 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 2)))
    print('TOP-3 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 3)))
    print('TOP-4 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 4)))
    print('TOP-5 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 5)))
    print('TOP-6 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 6)))
    print('TOP-7 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 7)))
    print('TOP-8 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 8)))
    print('TOP-9 Accuracy: {}'.format(top_k_accuracy_score(y_true, scores, k = 9)))
    print('AUC-ROC: {}'.format(roc_auc_score(y_true, scores, multi_class = 'ovo')))
    print(classification_report(y_true, y_predicted, target_names = test_set.classes, digits = 3))
# Out:
# Accuracy: 57.78%
# TOP-1 Accuracy: 0.5778
# TOP-2 Accuracy: 0.7653
# TOP-3 Accuracy: 0.855
# TOP-4 Accuracy: 0.9088
# TOP-5 Accuracy: 0.9444
# TOP-6 Accuracy: 0.9667
# TOP-7 Accuracy: 0.9804
# TOP-8 Accuracy: 0.9889
# TOP-9 Accuracy: 0.9956
# AUC-ROC: 0.9052326388888888
#               precision    recall  f1-score   support
#
#     airplane      0.638     0.649     0.643      1000
#   automobile      0.706     0.666     0.685      1000
#         bird      0.471     0.448     0.459      1000
#          cat      0.382     0.396     0.389      1000
#         deer      0.532     0.486     0.508      1000
#          dog      0.461     0.508     0.483      1000
#         frog      0.630     0.626     0.628      1000
#        horse      0.655     0.622     0.638      1000
#         ship      0.697     0.712     0.704      1000
#        truck      0.622     0.665     0.643      1000
#
#     accuracy                          0.578     10000
#    macro avg      0.579     0.578     0.578     10000
# weighted avg      0.579     0.578     0.578     10000

# %% [markdown]
# Таким образом, обучение и применение нейронных сетей, состоящих из полносвязных слоев, - достаточно сложные операции, требующие большого количества вычислений. Но и качество таких моделей, учитывая, что они не анализируют связность пикселей в картинке, достаточно высоко (более 50% ответов оказались верными). \
# Выбор оптимизатора и лосс-функции влияет на качество пренебрежимо мало. Гораздо более значительного улучшения можно добиться путем подбора архитектуры сети, а не способа ее обучения. В частности:
# - Добавление нормализации (BatchNorm) в скрытые слои позволяет заметно повысить качество
# - Используемая между полносвязными слоями нелинейная функция может оказывать значительное влияние на качество модели, но большинство функций, часто используемых на практике, показывают похожие результаты
# - Добавление скрытых слоев и нейронов в них позволяет заметно повысить качество модели, но лишь до некоторого предела, после которого качество либо не изменяется, либо уменьшается из-за переобучения
#
# В результате подбора всех параметров мне удалось достичь качества почти `58%` (вспомним, что обычная модель линейной регрессии показала качество лишь 41%). Также заметим, что верный класс оказывается среди двух наиболее вероятных по мнению модели в более, чем 75% случаев, а среди пяти - в почти 95%. Для обычной модели линейной регрессии эти метрики были соответственно 60% и 86%. Также заметим, что AUC-ROC и F-мера заметно увеличились и составили 0.905 и 0.578 соответственно против 0.82 и 0.409 для модели линейной регрессии.
#
# Таким образом, простейшая нейронная сеть показывает гораздо более хорошее качество, чем модель линейной регрессии.
