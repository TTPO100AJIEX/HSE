# %%
import numpy
import cvtda.classification

CLASSES = [ 'no', 'other', 'yandex', 'yango' ]

cvtda.classification.classify(
    None, None, numpy.load("1/front/train_labels.npy"), None,
    None, None, numpy.load("1/front/test_labels.npy"), None,
    without_diagrams = True, dump_name = "1/predictions",
    catboost_device = 'CPU', xgboost_device = 'cpu',
    only_get_from_dump = True, label_names = CLASSES
)
# Out:
# Trying KNeighborsClassifier - KNeighborsClassifier(n_jobs=-1, n_neighbors=50)
# Got the result from ./1/predictions/KNeighborsClassifier.npy
# {'classifier': 'Метод k ближайших соседей', 'Accuracy': 0.559, 'AUC-ROC': 0.8213486666666667, 'Precision': 0.5904102206697869, 'Recall': 0.5589999999999999, 'F1-score': 0.5530769791346021, 'TOP-2 Accuracy': 0.817, 'TOP-3 Accuracy': 0.9265}
# Trying RandomForestClassifier - RandomForestClassifier(n_jobs=-1, random_state=42)
# Got the result from ./1/predictions/RandomForestClassifier.npy
# {'classifier': 'Случайный лес', 'Accuracy': 0.756, 'AUC-ROC': 0.9228905, 'Precision': 0.7553394627990646, 'Recall': 0.756, 'F1-score': 0.7552983432514073, 'TOP-2 Accuracy': 0.9035, 'TOP-3 Accuracy': 0.972}
# Trying HistGradientBoostingClassifier - HistGradientBoostingClassifier(max_depth=4, max_features=0.1, max_iter=20,
#                                random_state=42, verbose=2)
# Got the result from ./1/predictions/HistGradientBoostingClassifier.npy
# {'classifier': 'Град. бустинг на основе гистограм', 'Accuracy': 0.772, 'AUC-ROC': 0.9321376666666668, 'Precision': 0.7730589668309262, 'Recall': 0.772, 'F1-score': 0.7721070536119392, 'TOP-2 Accuracy': 0.908, 'TOP-3 Accuracy': 0.976}
# Trying CatBoostClassifier - <catboost.core.CatBoostClassifier object at 0x000001F9B546B160>
# Got the result from ./1/predictions/CatBoostClassifier.npy
# {'classifier': 'CatBoost', 'Accuracy': 0.8165, 'AUC-ROC': 0.9474776666666666, 'Precision': 0.8157847780260461, 'Recall': 0.8165, 'F1-score': 0.8153331774010988, 'TOP-2 Accuracy': 0.9385, 'TOP-3 Accuracy': 0.9895}
# Trying XGBClassifier - XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=25, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)
# Got the result from ./1/predictions/XGBClassifier.npy
# {'classifier': 'XGBoost', 'Accuracy': 0.796, 'AUC-ROC': 0.9420516666666668, 'Precision': 0.7964007611605401, 'Recall': 0.7959999999999999, 'F1-score': 0.7960056926535837, 'TOP-2 Accuracy': 0.9265, 'TOP-3 Accuracy': 0.987}
# Trying NNClassifier_features - <cvtda.classification.NNClassifier.NNClassifier object at 0x000001F9B546B520>
# Got the result from ./1/predictions/NNClassifier_features.npy
# {'classifier': 'Нейронная сеть для тополог. признаков', 'Accuracy': 0.797, 'AUC-ROC': 0.9404253333333333, 'Precision': 0.7980442044511049, 'Recall': 0.7969999999999999, 'F1-score': 0.7973997071882677, 'TOP-2 Accuracy': 0.93, 'TOP-3 Accuracy': 0.9875}
# Skipping NNClassifier_diagrams - <cvtda.classification.NNClassifier.NNClassifier object at 0x000001F9B546B4F0>
# Trying NNClassifier_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x000001F9B546B4C0>
# Got the result from ./1/predictions/NNClassifier_images.npy
# {'classifier': 'ResNet50 – базовая модель', 'Accuracy': 0.784, 'AUC-ROC': 0.9254205, 'Precision': 0.7849402423821934, 'Recall': 0.784, 'F1-score': 0.7840771868426523, 'TOP-2 Accuracy': 0.9085, 'TOP-3 Accuracy': 0.976}
# Trying NNClassifier_features_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x000001F9B546B490>
# Got the result from ./1/predictions/NNClassifier_features_images.npy
# {'classifier': 'Комбинированная нейронная сеть', 'Accuracy': 0.782, 'AUC-ROC': 0.9275266666666667, 'Precision': 0.7825413620280638, 'Recall': 0.782, 'F1-score': 0.7821500172479113, 'TOP-2 Accuracy': 0.921, 'TOP-3 Accuracy': 0.975}
#                               classifier  Accuracy   AUC-ROC  Precision  \
# 0              Метод k ближайших соседей    0.5590  0.821349   0.590410
# 1                          Случайный лес    0.7560  0.922890   0.755339
# 2      Град. бустинг на основе гистограм    0.7720  0.932138   0.773059
# 3                               CatBoost    0.8165  0.947478   0.815785
# 4                                XGBoost    0.7960  0.942052   0.796401
# 5  Нейронная сеть для тополог. признаков    0.7970  0.940425   0.798044
# 6                                    NaN       NaN       NaN        NaN
# 7              ResNet50 – базовая модель    0.7840  0.925420   0.784940
# 8         Комбинированная нейронная сеть    0.7820  0.927527   0.782541
#
#    Recall  F1-score  TOP-2 Accuracy  TOP-3 Accuracy
# 0  0.5590  0.553077          0.8170          0.9265
# 1  0.7560  0.755298          0.9035          0.9720
# 2  0.7720  0.772107          0.9080          0.9760
# 3  0.8165  0.815333          0.9385          0.9895
# 4  0.7960  0.796006          0.9265          0.9870
# 5  0.7970  0.797400          0.9300          0.9875
# 6     NaN       NaN             NaN             NaN
# 7  0.7840  0.784077          0.9085          0.9760
# 8  0.7820  0.782150          0.9210          0.9750
