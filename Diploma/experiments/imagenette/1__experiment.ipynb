# %%
CLASSES = [
    "tench", "English springer", "cassette player", "chain saw", "church",
    "French horn", "garbage truck", "gas pump", "golf ball", "parachute"
]

# %% [markdown]
# # 64

# %%
import numpy
import torchvision
import torchvision.transforms.v2

transform = torchvision.transforms.v2.Compose([
    torchvision.transforms.v2.Resize((64, 64), antialias = True)
])

train = torchvision.datasets.Imagenette('imagenette', split = 'train', size = '160px', transform = transform, download = False)
test = torchvision.datasets.Imagenette('imagenette', split = 'val', size = '160px', transform = transform, download = False)

# %%
train_images = numpy.array([ numpy.array(item[0]) / 255 for item in train ])
train_labels = numpy.array([ item[1] for item in train ])

test_images = numpy.array([ numpy.array(item[0]) / 255 for item in test ])
test_labels = numpy.array([ item[1] for item in test ])

print(train_images.shape, test_images.shape)
# Out:
# (9469, 64, 64, 3) (3925, 64, 64, 3)

# %%
import cvtda.topology
extractor = cvtda.topology.FeatureExtractor(only_get_from_dump = True, return_diagrams = False)
extractor = extractor.fit(train_images, "1/64/train")
train_features = extractor.transform(train_images, "1/64/train")
test_features = extractor.transform(test_images, "1/64/test")
# Out:
# Calculating inverted images
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:02<00:00, 4140.45it/s]
# Got the result from ./1/64/train/greyscale/gray/features.npy
# Got the result from ./1/64/train/greyscale/gray/features.npy
# Got the result from ./1/64/train/greyscale/red/features.npy
# Got the result from ./1/64/train/greyscale/red/features.npy
# Got the result from ./1/64/train/greyscale/green/features.npy
# Got the result from ./1/64/train/greyscale/green/features.npy
# Got the result from ./1/64/train/greyscale/blue/features.npy
# Got the result from ./1/64/train/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5322.64it/s]
# Got the result from ./1/64/train/greyscale/gray/features.npy
# Got the result from ./1/64/train/greyscale/red/features.npy
# Got the result from ./1/64/train/greyscale/green/features.npy
# Got the result from ./1/64/train/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5482.92it/s]
# Got the result from ./1/64/train/inverted_greyscale/gray/features.npy
# Got the result from ./1/64/train/inverted_greyscale/gray/features.npy
# Got the result from ./1/64/train/inverted_greyscale/red/features.npy
# Got the result from ./1/64/train/inverted_greyscale/red/features.npy
# Got the result from ./1/64/train/inverted_greyscale/green/features.npy
# Got the result from ./1/64/train/inverted_greyscale/green/features.npy
# Got the result from ./1/64/train/inverted_greyscale/blue/features.npy
# Got the result from ./1/64/train/inverted_greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5599.63it/s]
# Got the result from ./1/64/train/inverted_greyscale/gray/features.npy
# Got the result from ./1/64/train/inverted_greyscale/red/features.npy
# Got the result from ./1/64/train/inverted_greyscale/green/features.npy
# Got the result from ./1/64/train/inverted_greyscale/blue/features.npy
# Fitting filtrations
# Calculated radial centers for images of size 64x64: [12 25 38 51]x[12 25 38 51]
# Fitting filtration 1/72: 2/HeightFiltrartion_-1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5631.23it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/gray/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/gray/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/red/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/red/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/green/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/green/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/blue/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/blue/features.npy
# Fitting filtration 2/72: 2/HeightFiltrartion_1_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5558.53it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/gray/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/gray/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/red/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/red/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/green/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/green/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/blue/features.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/blue/features.npy
# Fitting filtration 3/72: 2/HeightFiltrartion_1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 
features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_51/blue/features.npy
# Applying filtration 69/72: 6/RadialFiltration_51_12
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 10872.60it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/gray/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/red/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/green/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/blue/features.npy
# Applying filtration 70/72: 6/RadialFiltration_51_25
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 10473.61it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/gray/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/red/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/green/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/blue/features.npy
# Applying filtration 71/72: 6/RadialFiltration_51_38
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 10321.39it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/gray/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/red/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/green/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/blue/features.npy
# Applying filtration 72/72: 6/RadialFiltration_51_51
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 10842.47it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/gray/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/red/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/green/features.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/blue/features.npy
# RGB images received. Transforming to grayscale.
# Got the result from ./1/64/test/geometry/rgb/features.npy
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 9884.30it/s]
# Got the result from ./1/64/test/geometry/gray/features.npy
# Got the result from ./1/64/test/geometry/red/features.npy
# Got the result from ./1/64/test/geometry/green/features.npy
# Got the result from ./1/64/test/geometry/blue/features.npy
# Applying StandardScaler.

# %%
import cvtda.topology
extractor = cvtda.topology.FeatureExtractor(only_get_from_dump = True, return_diagrams = True)
extractor = extractor.fit(train_images, "1/64/train")
train_diagrams = extractor.transform(train_images, "1/64/train")
test_diagrams = extractor.transform(test_images, "1/64/test")
# Out:
# Calculating inverted images
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5641.39it/s]
# Got the result from ./1/64/train/greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/greyscale/gray/diagrams.npy
# Got the result from ./1/64/train/greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/greyscale/red/diagrams.npy
# Got the result from ./1/64/train/greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/greyscale/green/diagrams.npy
# Got the result from ./1/64/train/greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/greyscale/blue/diagrams.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5415.77it/s]
# Got the result from ./1/64/train/greyscale/gray/diagrams.npy
# Got the result from ./1/64/train/greyscale/red/diagrams.npy
# Got the result from ./1/64/train/greyscale/green/diagrams.npy
# Got the result from ./1/64/train/greyscale/blue/diagrams.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5209.85it/s]
# Got the result from ./1/64/train/inverted_greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/inverted_greyscale/gray/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/inverted_greyscale/red/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/inverted_greyscale/green/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/inverted_greyscale/blue/diagrams.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5339.13it/s]
# Got the result from ./1/64/train/inverted_greyscale/gray/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/red/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/green/diagrams.npy
# Got the result from ./1/64/train/inverted_greyscale/blue/diagrams.npy
# Fitting filtrations
# Calculated radial centers for images of size 64x64: [12 25 38 51]x[12 25 38 51]
# Fitting filtration 1/72: 2/HeightFiltrartion_-1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5382.10it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/gray/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/red/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/green/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_-1/blue/diagrams.npy
# Fitting filtration 2/72: 2/HeightFiltrartion_1_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5398.51it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/gray/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/red/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/green/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_1/blue/diagrams.npy
# Fitting filtration 3/72: 2/HeightFiltrartion_1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5217.08it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/gray/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/red/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/green/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_1_-1/blue/diagrams.npy
# Fitting filtration 4/72: 2/HeightFiltrartion_-1_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:01<00:00, 5263.90it/s]
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/gray/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/red/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1_1/green/diagrams.npy
# Got the result from ./1/64/train/filtrations/2/HeightFiltrartion_-1
/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_12/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_12/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_12/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_12/blue/diagrams.npy
# Applying filtration 62/72: 6/RadialFiltration_25_25
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 8526.96it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_25/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_25/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_25/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_25/blue/diagrams.npy
# Applying filtration 63/72: 6/RadialFiltration_25_38
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7843.83it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_38/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_38/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_38/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_38/blue/diagrams.npy
# Applying filtration 64/72: 6/RadialFiltration_25_51
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7384.65it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_51/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_51/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_51/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_25_51/blue/diagrams.npy
# Applying filtration 65/72: 6/RadialFiltration_38_12
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 8188.75it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_12/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_12/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_12/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_12/blue/diagrams.npy
# Applying filtration 66/72: 6/RadialFiltration_38_25
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7558.33it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_25/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_25/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_25/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_25/blue/diagrams.npy
# Applying filtration 67/72: 6/RadialFiltration_38_38
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 8377.57it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_38/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_38/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_38/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_38/blue/diagrams.npy
# Applying filtration 68/72: 6/RadialFiltration_38_51
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7621.37it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_51/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_51/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_51/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_38_51/blue/diagrams.npy
# Applying filtration 69/72: 6/RadialFiltration_51_12
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7897.41it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_12/blue/diagrams.npy
# Applying filtration 70/72: 6/RadialFiltration_51_25
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 8263.16it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_25/blue/diagrams.npy
# Applying filtration 71/72: 6/RadialFiltration_51_38
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 7889.94it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_38/blue/diagrams.npy
# Applying filtration 72/72: 6/RadialFiltration_51_51
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:00<00:00, 5609.82it/s]
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/gray/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/red/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/green/diagrams.npy
# Got the result from ./1/64/test/filtrations/6/RadialFiltration_51_51/blue/diagrams.npy
# Diagrams requested. Returning diagrams.

# %%
import cvtda.classification

cvtda.classification.classify(
    train_images, train_features, train_labels, None,
    test_images, test_features, test_labels, None,
    label_names = CLASSES, dump_name = "1/64/predictions",
    catboost_device = 'CPU', only_get_from_dump = True
)
# Out:
# Trying KNeighborsClassifier - KNeighborsClassifier(n_jobs=-1, n_neighbors=50)
# Got the result from ./1/64/predictions/KNeighborsClassifier.npy
# {'classifier': 'Метод k ближайших соседей', 'Accuracy': 0.5113375796178344, 'TOP-2 Accuracy': 0.6822929936305733, 'TOP-3 Accuracy': 0.780891719745223, 'TOP-4 Accuracy': 0.8412738853503184, 'TOP-5 Accuracy': 0.8881528662420383, 'TOP-6 Accuracy': 0.9248407643312102, 'TOP-7 Accuracy': 0.9546496815286625, 'TOP-8 Accuracy': 0.9737579617834395, 'TOP-9 Accuracy': 0.98828025477707, 'AUC-ROC': 0.8842205790136417, 'Precision': 0.5640660210924101, 'Recall': 0.5131724762246632, 'F1-score': 0.49990348115954425}
# Trying RandomForestClassifier - RandomForestClassifier(n_jobs=-1, random_state=42)
# Got the result from ./1/64/predictions/RandomForestClassifier.npy
# {'classifier': 'Случайный лес', 'Accuracy': 0.6020382165605096, 'TOP-2 Accuracy': 0.7561783439490446, 'TOP-3 Accuracy': 0.8310828025477707, 'TOP-4 Accuracy': 0.8802547770700637, 'TOP-5 Accuracy': 0.9146496815286624, 'TOP-6 Accuracy': 0.9380891719745222, 'TOP-7 Accuracy': 0.9579617834394905, 'TOP-8 Accuracy': 0.9717197452229299, 'TOP-9 Accuracy': 0.9870063694267516, 'AUC-ROC': 0.8989458684856564, 'Precision': 0.602007127274988, 'Recall': 0.6034124800723967, 'F1-score': 0.5998342921237759}
# Trying HistGradientBoostingClassifier - HistGradientBoostingClassifier(max_depth=4, max_features=0.1, max_iter=20,
#                                random_state=42, verbose=2)
# Got the result from ./1/64/predictions/HistGradientBoostingClassifier.npy
# {'classifier': 'Град. бустинг на основе гистограм', 'Accuracy': 0.6466242038216561, 'TOP-2 Accuracy': 0.7913375796178344, 'TOP-3 Accuracy': 0.8654777070063694, 'TOP-4 Accuracy': 0.9126114649681528, 'TOP-5 Accuracy': 0.9439490445859873, 'TOP-6 Accuracy': 0.9628025477707006, 'TOP-7 Accuracy': 0.977579617834395, 'TOP-8 Accuracy': 0.9864968152866243, 'TOP-9 Accuracy': 0.9938853503184714, 'AUC-ROC': 0.9280896299383878, 'Precision': 0.6469801770885086, 'Recall': 0.6472542739680333, 'F1-score': 0.6451483974015864}
# Trying CatBoostClassifier - <catboost.core.CatBoostClassifier object at 0x000002077956A2F0>
# Got the result from ./1/64/predictions/CatBoostClassifier.npy
# {'classifier': 'CatBoost', 'Accuracy': 0.7080254777070064, 'TOP-2 Accuracy': 0.8425477707006369, 'TOP-3 Accuracy': 0.9014012738853503, 'TOP-4 Accuracy': 0.9363057324840764, 'TOP-5 Accuracy': 0.9602547770700637, 'TOP-6 Accuracy': 0.9755414012738853, 'TOP-7 Accuracy': 0.9857324840764331, 'TOP-8 Accuracy': 0.9915923566878981, 'TOP-9 Accuracy': 0.996687898089172, 'AUC-ROC': 0.949828208347458, 'Precision': 0.7074502111908123, 'Recall': 0.7087096990366017, 'F1-score': 0.7065790855786908}
# Trying XGBClassifier - XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='gpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=25, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)
# Got the result from ./1/64/predictions/XGBClassifier.npy
# {'classifier': 'XGBoost', 'Accuracy': 0.6749044585987262, 'TOP-2 Accuracy': 0.8173248407643312, 'TOP-3 Accuracy': 0.8820382165605095, 'TOP-4 Accuracy': 0.9238216560509555, 'TOP-5 Accuracy': 0.9500636942675159, 'TOP-6 Accuracy': 0.9709554140127389, 'TOP-7 Accuracy': 0.9821656050955414, 'TOP-8 Accuracy': 0.9903184713375797, 'TOP-9 Accuracy': 0.9969426751592356, 'AUC-ROC': 0.9404595202444265, 'Precision': 0.6754727854042983, 'Recall': 0.6757045961507282, 'F1-score': 0.6751620284830789}
# Trying NNClassifier_features - <cvtda.classification.NNClassifier.NNClassifier object at 0x000002077956A0B0>
# Got the result from ./1/64/predictions/NNClassifier_features.npy
# {'classifier': 'Нейронная сеть для тополог. признаков', 'Accuracy': 0.6591082802547771, 'TOP-2 Accuracy': 0.7704458598726115, 'TOP-3 Accuracy': 0.8185987261146497, 'TOP-4 Accuracy': 0.8471337579617835, 'TOP-5 Accuracy': 0.8751592356687898, 'TOP-6 Accuracy': 0.9138853503184713, 'TOP-7 Accuracy': 0.9477707006369427, 'TOP-8 Accuracy': 0.9727388535031847, 'TOP-9 Accuracy': 0.9913375796178344, 'AUC-ROC': 0.9238221782515353, 'Precision': 0.5971323538449266, 'Recall': 0.6587613430339416, 'F1-score': 0.6252430317567746}
# Trying NNClassifier_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x0000020779569F60>
# Got the result from ./1/64/predictions/NNClassifier_images.npy
# {'classifier': 'ResNet18 – базовая модель', 'Accuracy': 0.489171974522293, 'TOP-2 Accuracy': 0.606624203821656, 'TOP-3 Accuracy': 0.6942675159235668, 'TOP-4 Accuracy': 0.7577070063694268, 'TOP-5 Accuracy': 0.8168152866242038, 'TOP-6 Accuracy': 0.8619108280254777, 'TOP-7 Accuracy': 0.9077707006369427, 'TOP-8 Accuracy': 0.9444585987261146, 'TOP-9 Accuracy': 0.9732484076433121, 'AUC-ROC': 0.8215760344647849, 'Precision': 0.4308950593198569, 'Recall': 0.4930062980161913, 'F1-score': 0.4508153687101415}
# Trying NNClassifier_features_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x0000020779569DB0>
# Got the result from ./1/64/predictions/NNClassifier_features_images.npy
# {'classifier': 'Комбинированная нейронная сеть', 'Accuracy': 0.6119745222929937, 'TOP-2 Accuracy': 0.738343949044586, 'TOP-3 Accuracy': 0.8109554140127389, 'TOP-4 Accuracy': 0.8624203821656051, 'TOP-5 Accuracy': 0.9026751592356688, 'TOP-6 Accuracy': 0.9332484076433121, 'TOP-7 Accuracy': 0.9554140127388535, 'TOP-8 Accuracy': 0.9712101910828026, 'TOP-9 Accuracy': 0.9862420382165605, 'AUC-ROC': 0.9074389862451079, 'Precision': 0.6186356904133687, 'Recall': 0.6111564182743805, 'F1-score': 0.586672109083886}
#                               classifier  Accuracy  TOP-2 Accuracy  \
# 0              Метод k ближайших соседей  0.511338        0.682293
# 1                          Случайный лес  0.602038        0.756178
# 2      Град. бустинг на основе гистограм  0.646624        0.791338
# 3                               CatBoost  0.708025        0.842548
# 4                                XGBoost  0.674904        0.817325
# 5  Нейронная сеть для тополог. признаков  0.659108        0.770446
# 6                                    NaN       NaN             NaN
# 7              ResNet18 – базовая модель  0.489172        0.606624
# 8         Комбинированная нейронная сеть  0.611975        0.738344
#
#    TOP-3 Accuracy  TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  \
# 0        0.780892        0.841274        0.888153        0.924841
# 1        0.831083        0.880255        0.914650        0.938089
# 2        0.865478        0.912611        0.943949        0.962803
# 3        0.901401        0.936306        0.960255        0.975541
# 4        0.882038        0.923822        0.950064        0.970955
# 5        0.818599        0.847134        0.875159        0.913885
# 6             NaN             NaN             NaN             NaN
# 7        0.694268        0.757707        0.816815        0.861911
# 8        0.810955        0.862420        0.902675        0.933248
#
#    TOP-7 Accuracy  TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  \
# 0        0.954650        0.973758        0.988280  0.884221   0.564066
# 1        0.957962        0.971720        0.987006  0.898946   0.602007
# 2        0.977580        0.986497        0.993885  0.928090   0.646980
# 3        0.985732        0.991592        0.996688  0.949828   0.707450
# 4        0.982166        0.990318        0.996943  0.940460   0.675473
# 5        0.947771        0.972739        0.991338  0.923822   0.597132
# 6             NaN             NaN             NaN       NaN        NaN
# 7        0.907771        0.944459        0.973248  0.821576   0.430895
# 8        0.955414        0.971210        0.986242  0.907439   0.618636
#
#      Recall  F1-score
# 0  0.513172  0.499903
# 1  0.603412  0.599834
# 2  0.647254  0.645148
# 3  0.708710  0.706579
# 4  0.675705  0.675162
# 5  0.658761  0.625243
# 6       NaN       NaN
# 7  0.493006  0.450815
# 8  0.611156  0.586672

# %% [markdown]
# # Cleanup

# %%
del train
del test
del train_images
del train_features
del train_labels
del train_diagrams
del test_images
del test_features
del test_labels
del test_diagrams

# %%
import gc
gc.collect()
# Out:
# 92057

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# # 128

# %%
import numpy
import torchvision
import torchvision.transforms.v2

transform = torchvision.transforms.v2.Compose([
    torchvision.transforms.v2.Resize((128, 128), antialias = True)
])

train = torchvision.datasets.Imagenette('imagenette', split = 'train', size = '160px', transform = transform, download = False)
test = torchvision.datasets.Imagenette('imagenette', split = 'val', size = '160px', transform = transform, download = False)

# %%
train_images = numpy.array([ numpy.array(item[0]) / 255 for item in train ])
train_labels = numpy.array([ item[1] for item in train ])

test_images = numpy.array([ numpy.array(item[0]) / 255 for item in test ])
test_labels = numpy.array([ item[1] for item in test ])

print(train_images.shape, test_images.shape)
# Out:
# (9469, 128, 128, 3) (3925, 128, 128, 3)

# %%
import cvtda.topology
extractor = cvtda.topology.FeatureExtractor(only_get_from_dump = False, return_diagrams = False)
extractor = extractor.fit(train_images, "1/128/train")
train_features = extractor.transform(train_images, "1/128/train")
test_features = extractor.transform(test_images, "1/128/test")
# Out:
# Calculating inverted images
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1104.62it/s]
# GreyscaleExtractor: processing 1/128/train/greyscale/gray, do_fit = True
# Got the result from ./1/128/train/greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/greyscale/gray/features.npy
# Got the result from ./1/128/train/greyscale/gray/features.npy
# GreyscaleExtractor: processing 1/128/train/greyscale/red, do_fit = True
# Got the result from ./1/128/train/greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/greyscale/red/features.npy
# Got the result from ./1/128/train/greyscale/red/features.npy
# GreyscaleExtractor: processing 1/128/train/greyscale/green, do_fit = True
# Got the result from ./1/128/train/greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/greyscale/green/features.npy
# Got the result from ./1/128/train/greyscale/green/features.npy
# GreyscaleExtractor: processing 1/128/train/greyscale/blue, do_fit = True
# Got the result from ./1/128/train/greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/greyscale/blue/features.npy
# Got the result from ./1/128/train/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:09<00:00, 1035.50it/s]
# Got the result from ./1/128/train/greyscale/gray/features.npy
# Got the result from ./1/128/train/greyscale/red/features.npy
# Got the result from ./1/128/train/greyscale/green/features.npy
# Got the result from ./1/128/train/greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1075.26it/s]
# GreyscaleExtractor: processing 1/128/train/inverted_greyscale/gray, do_fit = True
# Got the result from ./1/128/train/inverted_greyscale/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/inverted_greyscale/gray/features.npy
# Got the result from ./1/128/train/inverted_greyscale/gray/features.npy
# GreyscaleExtractor: processing 1/128/train/inverted_greyscale/red, do_fit = True
# Got the result from ./1/128/train/inverted_greyscale/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/inverted_greyscale/red/features.npy
# Got the result from ./1/128/train/inverted_greyscale/red/features.npy
# GreyscaleExtractor: processing 1/128/train/inverted_greyscale/green, do_fit = True
# Got the result from ./1/128/train/inverted_greyscale/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/inverted_greyscale/green/features.npy
# Got the result from ./1/128/train/inverted_greyscale/green/features.npy
# GreyscaleExtractor: processing 1/128/train/inverted_greyscale/blue, do_fit = True
# Got the result from ./1/128/train/inverted_greyscale/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/inverted_greyscale/blue/features.npy
# Got the result from ./1/128/train/inverted_greyscale/blue/features.npy
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1091.62it/s]
# Got the result from ./1/128/train/inverted_greyscale/gray/features.npy
# Got the result from ./1/128/train/inverted_greyscale/red/features.npy
# Got the result from ./1/128/train/inverted_greyscale/green/features.npy
# Got the result from ./1/128/train/inverted_greyscale/blue/features.npy
# Fitting filtrations
# Calculated radial centers for images of size 128x128: [ 24  50  77 103]x[ 24  50  77 103]
# Fitting filtration 1/72: 2/HeightFiltrartion_-1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1074.30it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_-1/gray, do_fit = True, filtration = HeightFiltration(direction=array([-1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_-1/red, do_fit = True, filtration = HeightFiltration(direction=array([-1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_-1/green, do_fit = True, filtration = HeightFiltration(direction=array([-1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_-1/blue, do_fit = True, filtration = HeightFiltration(direction=array([-1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_-1/blue/features.npy
# Fitting filtration 2/72: 2/HeightFiltrartion_1_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1097.75it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_1/gray, do_fit = True, filtration = HeightFiltration(direction=array([1, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_1/red, do_fit = True, filtration = HeightFiltration(direction=array([1, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_1/green, do_fit = True, filtration = HeightFiltration(direction=array([1, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_1/blue, do_fit = True, filtration = HeightFiltration(direction=array([1, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_1/blue/features.npy
# Fitting filtration 3/72: 2/HeightFiltrartion_1_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1107.42it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_-1/gray, do_fit = True, filtration = HeightFiltration(direction=array([ 1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_-1/red, do_fit = True, filtration = HeightFiltration(direction=array([ 1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_-1/green, do_fit = True, filtration = HeightFiltration(direction=array([ 1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_-1/blue, do_fit = True, filtration = HeightFiltration(direction=array([ 1, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_-1/blue/features.npy
# Fitting filtration 4/72: 2/HeightFiltrartion_-1_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1086.20it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_1/gray, do_fit = True, filtration = HeightFiltration(direction=array([-1,  1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_1/red, do_fit = True, filtration = HeightFiltration(direction=array([-1,  1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_1/green, do_fit = True, filtration = HeightFiltration(direction=array([-1,  1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_1/blue, do_fit = True, filtration = HeightFiltration(direction=array([-1,  1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_1/blue/features.npy
# Fitting filtration 5/72: 2/HeightFiltrartion_0_-1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1061.46it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_-1/gray, do_fit = True, filtration = HeightFiltration(direction=array([ 0, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_-1/red, do_fit = True, filtration = HeightFiltration(direction=array([ 0, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_-1/green, do_fit = True, filtration = HeightFiltration(direction=array([ 0, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_-1/blue, do_fit = True, filtration = HeightFiltration(direction=array([ 0, -1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_-1/blue/features.npy
# Fitting filtration 6/72: 2/HeightFiltrartion_0_1
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1177.06it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_1/gray, do_fit = True, filtration = HeightFiltration(direction=array([0, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_1/red, do_fit = True, filtration = HeightFiltration(direction=array([0, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_1/green, do_fit = True, filtration = HeightFiltration(direction=array([0, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_0_1/blue, do_fit = True, filtration = HeightFiltration(direction=array([0, 1]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_0_1/blue/features.npy
# Fitting filtration 7/72: 2/HeightFiltrartion_-1_0
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1121.78it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_0/gray, do_fit = True, filtration = HeightFiltration(direction=array([-1,  0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_0/red, do_fit = True, filtration = HeightFiltration(direction=array([-1,  0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_0/green, do_fit = True, filtration = HeightFiltration(direction=array([-1,  0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_-1_0/blue, do_fit = True, filtration = HeightFiltration(direction=array([-1,  0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_-1_0/blue/features.npy
# Fitting filtration 8/72: 2/HeightFiltrartion_1_0
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1129.13it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_0/gray, do_fit = True, filtration = HeightFiltration(direction=array([1, 0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_0/red, do_fit = True, filtration = HeightFiltration(direction=array([1, 0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/red/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_0/green, do_fit = True, filtration = HeightFiltration(direction=array([1, 0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/green/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/HeightFiltrartion_1_0/blue, do_fit = True, filtration = HeightFiltration(direction=array([1, 0]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/HeightFiltrartion_1_0/blue/features.npy
# Fitting filtration 9/72: 2/RadialFiltration_24_24
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1174.83it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_24/gray, do_fit = True, filtration = RadialFiltration(center=array([24, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_24/red, do_fit = True, filtration = RadialFiltration(center=array([24, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_24/green, do_fit = True, filtration = RadialFiltration(center=array([24, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_24/blue, do_fit = True, filtration = RadialFiltration(center=array([24, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_24/blue/features.npy
# Fitting filtration 10/72: 2/RadialFiltration_24_50
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1077.31it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_50/gray, do_fit = True, filtration = RadialFiltration(center=array([24, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_50/red, do_fit = True, filtration = RadialFiltration(center=array([24, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_50/green, do_fit = True, filtration = RadialFiltration(center=array([24, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_50/blue, do_fit = True, filtration = RadialFiltration(center=array([24, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_50/blue/features.npy
# Fitting filtration 11/72: 2/RadialFiltration_24_77
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1163.43it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_77/gray, do_fit = True, filtration = RadialFiltration(center=array([24, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_77/red, do_fit = True, filtration = RadialFiltration(center=array([24, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_77/green, do_fit = True, filtration = RadialFiltration(center=array([24, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_77/blue, do_fit = True, filtration = RadialFiltration(center=array([24, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_77/blue/features.npy
# Fitting filtration 12/72: 2/RadialFiltration_24_103
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:07<00:00, 1183.98it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_103/gray, do_fit = True, filtration = RadialFiltration(center=array([ 24, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_103/red, do_fit = True, filtration = RadialFiltration(center=array([ 24, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_103/green, do_fit = True, filtration = RadialFiltration(center=array([ 24, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_24_103/blue, do_fit = True, filtration = RadialFiltration(center=array([ 24, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_24_103/blue/features.npy
# Fitting filtration 13/72: 2/RadialFiltration_50_24
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:07<00:00, 1188.23it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_24/gray, do_fit = True, filtration = RadialFiltration(center=array([50, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_24/red, do_fit = True, filtration = RadialFiltration(center=array([50, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_24/green, do_fit = True, filtration = RadialFiltration(center=array([50, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_24/blue, do_fit = True, filtration = RadialFiltration(center=array([50, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_24/blue/features.npy
# Fitting filtration 14/72: 2/RadialFiltration_50_50
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1164.98it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_50/gray, do_fit = True, filtration = RadialFiltration(center=array([50, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_50/red, do_fit = True, filtration = RadialFiltration(center=array([50, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_50/green, do_fit = True, filtration = RadialFiltration(center=array([50, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_50/blue, do_fit = True, filtration = RadialFiltration(center=array([50, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_50/blue/features.npy
# Fitting filtration 15/72: 2/RadialFiltration_50_77
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1183.33it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_77/gray, do_fit = True, filtration = RadialFiltration(center=array([50, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_77/red, do_fit = True, filtration = RadialFiltration(center=array([50, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_77/green, do_fit = True, filtration = RadialFiltration(center=array([50, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_77/blue, do_fit = True, filtration = RadialFiltration(center=array([50, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_77/blue/features.npy
# Fitting filtration 16/72: 2/RadialFiltration_50_103
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1170.40it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_103/gray, do_fit = True, filtration = RadialFiltration(center=array([ 50, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_103/red, do_fit = True, filtration = RadialFiltration(center=array([ 50, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_103/green, do_fit = True, filtration = RadialFiltration(center=array([ 50, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_50_103/blue, do_fit = True, filtration = RadialFiltration(center=array([ 50, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_50_103/blue/features.npy
# Fitting filtration 17/72: 2/RadialFiltration_77_24
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1156.87it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_24/gray, do_fit = True, filtration = RadialFiltration(center=array([77, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_24/red, do_fit = True, filtration = RadialFiltration(center=array([77, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_24/green, do_fit = True, filtration = RadialFiltration(center=array([77, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_24/blue, do_fit = True, filtration = RadialFiltration(center=array([77, 24]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_24/blue/features.npy
# Fitting filtration 18/72: 2/RadialFiltration_77_50
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1139.83it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_50/gray, do_fit = True, filtration = RadialFiltration(center=array([77, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_50/red, do_fit = True, filtration = RadialFiltration(center=array([77, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_50/green, do_fit = True, filtration = RadialFiltration(center=array([77, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_50/blue, do_fit = True, filtration = RadialFiltration(center=array([77, 50]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_50/blue/features.npy
# Fitting filtration 19/72: 2/RadialFiltration_77_77
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:07<00:00, 1184.18it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_77/gray, do_fit = True, filtration = RadialFiltration(center=array([77, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_77/red, do_fit = True, filtration = RadialFiltration(center=array([77, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_77/green, do_fit = True, filtration = RadialFiltration(center=array([77, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_77/blue, do_fit = True, filtration = RadialFiltration(center=array([77, 77]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/blue/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_77/blue/features.npy
# Fitting filtration 20/72: 2/RadialFiltration_77_103
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 9469/9469 [00:08<00:00, 1160.38it/s]
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_103/gray, do_fit = True, filtration = RadialFiltration(center=array([ 77, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/gray/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/gray/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/gray/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_103/red, do_fit = True, filtration = RadialFiltration(center=array([ 77, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/red/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/red/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/red/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_103/green, do_fit = True, filtration = RadialFiltration(center=array([ 77, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/green/diagrams.npy
# Applying Scaler to persistence diagrams.
# DiagramVectorizer: fitting complete
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/green/features.npy
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/green/features.npy
# FiltrationExtractor: processing 1/128/train/filtrations/2/RadialFiltration_77_103/blue, do_fit = True, filtration = RadialFiltration(center=array([ 77, 103]), n_jobs=-1)
# Got the result from ./1/128/train/filtrations/2/RadialFiltration_77_103/blue/diagrams.npy
# Applying Scaler to persistence diagrams.
# ...
# Got the result from ./1/128/test/filtrations/4/RadialFiltration_77_77/blue/features.npy
# Applying filtration 44/72: 4/RadialFiltration_77_103
# RGB images received. Transforming to grayscale.
# rgb2gray: 100%|██████████| 3925/3925 [00:02<00:00, 
features.npy
# Got the result from ./1/128/test/filtrations/6/RadialFiltration_103_103/green/features.npy
# Got the result from ./1/128/test/filtrations/6/RadialFiltration_103_103/blue/features.npy
# RGB images received. Transforming to grayscale.
# RGBGeometryExtractor: 100%|██████████| 3925/3925 [00:05<00:00, 747.83it/s]
# Saving the result to ./1/128/test/geometry/rgb/features.npy
# rgb2gray: 100%|██████████| 3925/3925 [00:03<00:00, 1290.06it/s]
# GrayGeometryExtractor: 100%|██████████| 3925/3925 [02:05<00:00, 31.16it/s]
# Saving the result to ./1/128/test/geometry/gray/features.npy
# GrayGeometryExtractor: 100%|██████████| 3925/3925 [02:06<00:00, 30.91it/s]
# Saving the result to ./1/128/test/geometry/red/features.npy
# GrayGeometryExtractor: 100%|██████████| 3925/3925 [02:06<00:00, 31.08it/s]
# Saving the result to ./1/128/test/geometry/green/features.npy
# GrayGeometryExtractor: 100%|██████████| 3925/3925 [02:06<00:00, 30.98it/s]
# Saving the result to ./1/128/test/geometry/blue/features.npy
# Applying StandardScaler.

# %%
if False:
    import cvtda.topology
    extractor = cvtda.topology.FeatureExtractor(only_get_from_dump = True, return_diagrams = True)
    extractor = extractor.fit(train_images, "1/128/train")
    train_diagrams = extractor.transform(train_images, "1/128/train")
    test_diagrams = extractor.transform(test_images, "1/128/test")

# %%
numpy.save("1/128/train_features.npy", train_features)
numpy.save("1/128/test_features.npy", test_features)

# %%
train_features.shape
# Out:
# (9469, 60191)

# %%
import cvtda.classification

cvtda.classification.classify(
    train_images, train_features, train_labels, None,
    test_images, test_features, test_labels, None,
    label_names = CLASSES, dump_name = "1/128/predictions",
    catboost_device = 'CPU', xgboost_device = 'cpu', only_get_from_dump = True
)
# Out:
# Trying KNeighborsClassifier - KNeighborsClassifier(n_jobs=-1, n_neighbors=50)
# Got the result from ./1/128/predictions/KNeighborsClassifier.npy
# {'classifier': 'Метод k ближайших соседей', 'Accuracy': 0.5378343949044586, 'TOP-2 Accuracy': 0.6917197452229299, 'TOP-3 Accuracy': 0.7793630573248408, 'TOP-4 Accuracy': 0.8338853503184713, 'TOP-5 Accuracy': 0.8835668789808917, 'TOP-6 Accuracy': 0.916687898089172, 'TOP-7 Accuracy': 0.9472611464968153, 'TOP-8 Accuracy': 0.9673885350318472, 'TOP-9 Accuracy': 0.990063694267516, 'AUC-ROC': 0.8961687660000416, 'Precision': 0.6228602023547547, 'Recall': 0.5388982513318349, 'F1-score': 0.5126153613391033}
# Trying RandomForestClassifier - RandomForestClassifier(n_jobs=-1, random_state=42)
# Got the result from ./1/128/predictions/RandomForestClassifier.npy
# {'classifier': 'Случайный лес', 'Accuracy': 0.6040764331210191, 'TOP-2 Accuracy': 0.759235668789809, 'TOP-3 Accuracy': 0.8328662420382166, 'TOP-4 Accuracy': 0.88, 'TOP-5 Accuracy': 0.9174522292993631, 'TOP-6 Accuracy': 0.9439490445859873, 'TOP-7 Accuracy': 0.9622929936305733, 'TOP-8 Accuracy': 0.9773248407643312, 'TOP-9 Accuracy': 0.9898089171974522, 'AUC-ROC': 0.902227845821577, 'Precision': 0.6044617474669708, 'Recall': 0.606078951114938, 'F1-score': 0.60052648609332}
# Trying HistGradientBoostingClassifier - HistGradientBoostingClassifier(max_depth=4, max_features=0.1, max_iter=20,
#                                random_state=42, verbose=2)
# Got the result from ./1/128/predictions/HistGradientBoostingClassifier.npy
# {'classifier': 'Град. бустинг на основе гистограм', 'Accuracy': 0.6532484076433122, 'TOP-2 Accuracy': 0.796687898089172, 'TOP-3 Accuracy': 0.8736305732484076, 'TOP-4 Accuracy': 0.9146496815286624, 'TOP-5 Accuracy': 0.9444585987261146, 'TOP-6 Accuracy': 0.9643312101910828, 'TOP-7 Accuracy': 0.9768152866242038, 'TOP-8 Accuracy': 0.9867515923566879, 'TOP-9 Accuracy': 0.9943949044585987, 'AUC-ROC': 0.9313162931022438, 'Precision': 0.6535549805040352, 'Recall': 0.6541455261049577, 'F1-score': 0.6518495001335423}
# Trying CatBoostClassifier - <catboost.core.CatBoostClassifier object at 0x0000020A29D73490>
# Got the result from ./1/128/predictions/CatBoostClassifier.npy
# {'classifier': 'CatBoost', 'Accuracy': 0.7329936305732484, 'TOP-2 Accuracy': 0.8634394904458599, 'TOP-3 Accuracy': 0.9182165605095541, 'TOP-4 Accuracy': 0.9457324840764331, 'TOP-5 Accuracy': 0.9668789808917198, 'TOP-6 Accuracy': 0.9796178343949045, 'TOP-7 Accuracy': 0.9872611464968153, 'TOP-8 Accuracy': 0.9926114649681529, 'TOP-9 Accuracy': 0.9974522292993631, 'AUC-ROC': 0.9576663325749866, 'Precision': 0.731954331100239, 'Recall': 0.7336220893786936, 'F1-score': 0.7316497386547919}
# Trying XGBClassifier - XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=25, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)
# Got the result from ./1/128/predictions/XGBClassifier.npy
# {'classifier': 'XGBoost', 'Accuracy': 0.6970700636942675, 'TOP-2 Accuracy': 0.8354140127388535, 'TOP-3 Accuracy': 0.9001273885350318, 'TOP-4 Accuracy': 0.935031847133758, 'TOP-5 Accuracy': 0.9569426751592357, 'TOP-6 Accuracy': 0.9719745222929936, 'TOP-7 Accuracy': 0.9801273885350319, 'TOP-8 Accuracy': 0.990828025477707, 'TOP-9 Accuracy': 0.9964331210191083, 'AUC-ROC': 0.9477586512210321, 'Precision': 0.695962445964897, 'Recall': 0.6978617636625459, 'F1-score': 0.6959821489637177}
# Trying NNClassifier_features - <cvtda.classification.NNClassifier.NNClassifier object at 0x0000020A29D72920>
# Got the result from ./1/128/predictions/NNClassifier_features.npy
# {'classifier': 'Нейронная сеть для тополог. признаков', 'Accuracy': 0.6761783439490446, 'TOP-2 Accuracy': 0.7852229299363057, 'TOP-3 Accuracy': 0.8262420382165605, 'TOP-4 Accuracy': 0.8608917197452229, 'TOP-5 Accuracy': 0.8950318471337579, 'TOP-6 Accuracy': 0.9304458598726114, 'TOP-7 Accuracy': 0.9587261146496815, 'TOP-8 Accuracy': 0.9780891719745223, 'TOP-9 Accuracy': 0.9915923566878981, 'AUC-ROC': 0.9324596290282813, 'Precision': 0.6118594322219642, 'Recall': 0.6756951591064113, 'F1-score': 0.6408932361515953}
# Trying NNClassifier_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x0000020A29D70220>
# Got the result from ./1/128/predictions/NNClassifier_images.npy
# {'classifier': 'ResNet18 – базовая модель', 'Accuracy': 0.5212738853503185, 'TOP-2 Accuracy': 0.6422929936305732, 'TOP-3 Accuracy': 0.7240764331210191, 'TOP-4 Accuracy': 0.7895541401273886, 'TOP-5 Accuracy': 0.8445859872611465, 'TOP-6 Accuracy': 0.8881528662420383, 'TOP-7 Accuracy': 0.9192356687898089, 'TOP-8 Accuracy': 0.9464968152866242, 'TOP-9 Accuracy': 0.9729936305732484, 'AUC-ROC': 0.8454976613837071, 'Precision': 0.5757592894296002, 'Recall': 0.5212991477246405, 'F1-score': 0.5032233977437314}
# Trying NNClassifier_features_images - <cvtda.classification.NNClassifier.NNClassifier object at 0x0000020A29D722C0>
# Got the result from ./1/128/predictions/NNClassifier_features_images.npy
# {'classifier': 'Комбинированная нейронная сеть', 'Accuracy': 0.6657324840764332, 'TOP-2 Accuracy': 0.7768152866242038, 'TOP-3 Accuracy': 0.8326114649681529, 'TOP-4 Accuracy': 0.882547770700637, 'TOP-5 Accuracy': 0.9192356687898089, 'TOP-6 Accuracy': 0.9457324840764331, 'TOP-7 Accuracy': 0.966624203821656, 'TOP-8 Accuracy': 0.9826751592356688, 'TOP-9 Accuracy': 0.9915923566878981, 'AUC-ROC': 0.9274258284894589, 'Precision': 0.6233913111091678, 'Recall': 0.6646319496859284, 'F1-score': 0.6367706210753775}
#                               classifier  Accuracy  TOP-2 Accuracy  \
# 0              Метод k ближайших соседей  0.537834        0.691720
# 1                          Случайный лес  0.604076        0.759236
# 2      Град. бустинг на основе гистограм  0.653248        0.796688
# 3                               CatBoost  0.732994        0.863439
# 4                                XGBoost  0.697070        0.835414
# 5  Нейронная сеть для тополог. признаков  0.676178        0.785223
# 6                                    NaN       NaN             NaN
# 7              ResNet18 – базовая модель  0.521274        0.642293
# 8         Комбинированная нейронная сеть  0.665732        0.776815
#
#    TOP-3 Accuracy  TOP-4 Accuracy  TOP-5 Accuracy  TOP-6 Accuracy  \
# 0        0.779363        0.833885        0.883567        0.916688
# 1        0.832866        0.880000        0.917452        0.943949
# 2        0.873631        0.914650        0.944459        0.964331
# 3        0.918217        0.945732        0.966879        0.979618
# 4        0.900127        0.935032        0.956943        0.971975
# 5        0.826242        0.860892        0.895032        0.930446
# 6             NaN             NaN             NaN             NaN
# 7        0.724076        0.789554        0.844586        0.888153
# 8        0.832611        0.882548        0.919236        0.945732
#
#    TOP-7 Accuracy  TOP-8 Accuracy  TOP-9 Accuracy   AUC-ROC  Precision  \
# 0        0.947261        0.967389        0.990064  0.896169   0.622860
# 1        0.962293        0.977325        0.989809  0.902228   0.604462
# 2        0.976815        0.986752        0.994395  0.931316   0.653555
# 3        0.987261        0.992611        0.997452  0.957666   0.731954
# 4        0.980127        0.990828        0.996433  0.947759   0.695962
# 5        0.958726        0.978089        0.991592  0.932460   0.611859
# 6             NaN             NaN             NaN       NaN        NaN
# 7        0.919236        0.946497        0.972994  0.845498   0.575759
# 8        0.966624        0.982675        0.991592  0.927426   0.623391
#
#      Recall  F1-score
# 0  0.538898  0.512615
# 1  0.606079  0.600526
# 2  0.654146  0.651850
# 3  0.733622  0.731650
# 4  0.697862  0.695982
# 5  0.675695  0.640893
# 6       NaN       NaN
# 7  0.521299  0.503223
# 8  0.664632  0.636771
